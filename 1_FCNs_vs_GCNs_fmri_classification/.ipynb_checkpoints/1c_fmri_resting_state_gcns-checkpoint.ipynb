# %% [markdown]
# ## Application of FCNs & GCNs to fmri movie data (camcan study)
#
# - Application of FCNs (Fully connected networks) and GCNs (Graphical Neural Networks - 1st order, 5th order, 8th order) to fmri data to classify time blocks of fmri data across subjects
# - Fmri data (camcan study) recorded while subjects watched a Hitchcock movie

# %% [markdown]
# #### Glossary
# - __TR__: Repetition time = 2.47 (time it takes to scan all slices)
# - __fmri data__: 193 Timepoints (193 x 2.47 = 476 secs = 7.9 mins) x 400 ROIs
#
#     __python scripts__
# - __util_funcs__ - contains functions used to load the fmri camcan data and to split the data into time blocks which the models try and classify
# - __model.py__ - contains the FCN and GCN models

# %% [markdown]
# ### Contents

# %% [markdown]
# * [Results summary](#results)
# * [imports](#imports)
#
#
# * [1. Data](#data)
# * [2. Inspect data](#inspect_data)
# * [3. Fmri - filtered & normalised](#filter_norm)
#     * [3.1 Data loader](#data_loader)
#     * [3.2. FCNs](#fcn)
#     - Block durations of 6,8,
#     * [3.3. GCNs](#gcn)
#     - first order, 5th order neighbourhood
# * [4. Fmri - filtered only](#filter)
#     * [4.1 Data loader](#data_loader2)
#     * [4.2 FCNs](#fcn2)
#     - Block durations of 6,8,16
#     * [4.3 GCNs](#gcn2)
#     - first order, 5th order neighbourhood
#
# * [5. Repeated_trials](#repeated_trials)

# %% [markdown]
# ## Results summary <a class="anchor" id="results"></a>
# - FCN best performing

# %%
#Results
row_headers = [np.array(['filtered_&_norm','filtered_&_norm','filtered_&_norm', 'filtered', 'filtered', 'filtered']), np.array(['6','8','16','6','8','16'])]
results = [[0.931, 0.463, 0.694, 0.696],[0.89, 0.509, 0.825, 0.770],[0.927, 0.615, 0.844, 0.823],[0.873, 0.471, 0.729, 0.665],[0.89, 0.526, 0.771, 0.731],[0.930, 0.662, 0.842, 0.819]]
column_names = ['FCN - Fully Connected', 'GCN_1st_order', 'GCN_5th_order', 'GCN_8th_order']
df = pd.DataFrame(results, columns= column_names, index=row_headers)
#Save results
results = df.to_csv('model_results.csv')
df
# Out:
#                     FCN - Fully Connected  GCN_1st_order  GCN_5th_order  \
# filtered_&_norm 6                   0.931          0.463          0.694
#                 8                   0.890          0.509          0.825
#                 16                  0.927          0.615          0.844
# filtered        6                   0.873          0.471          0.729
#                 8                   0.890          0.526          0.771
#                 16                  0.930          0.662          0.842
#
#                     GCN_8th_order
# filtered_&_norm 6           0.696
#                 8           0.770
#                 16          0.823
# filtered        6           0.665
#                 8           0.731
#                 16          0.819

# %% [markdown]
# ### Plot results
#
# __i. Filtered & normalised__

# %%
#Plot results
df1 = df.loc['filtered_&_norm', column_names]
df1['block_duration'] = df1.index
ax1 = df1.plot(kind='scatter', x="block_duration", y='FCN - Fully Connected', color='blue', title = 'FCN vs GCN Model Accuracy - fmri filtered & normalised', figsize=(9,7))  
ax2 = df1.plot(kind='scatter', x="block_duration", y='GCN_1st_order', color='orange', ax=ax1)  
ax3 = df1.plot(kind='scatter', x="block_duration", y='GCN_5th_order', color='g', ax=ax1)
ax3 = df1.plot(kind='scatter', x="block_duration", y='GCN_8th_order', color='r', ax=ax1)
ax4 = df1.plot(x="block_duration", y=column_names, linestyle='dashed', ax = ax1);
ax4.set_ylabel("Model Accuracy")
# Out:
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Text(0, 0.5, 'Model Accuracy')

# %% [markdown]
# __ii. Filtered only__

# %%
#Plot results
df2 = df.loc['filtered', column_names]
df2['block_duration'] = df2.index
ax1 = df2.plot(kind='scatter', x="block_duration", y='FCN - Fully Connected', color='blue', title = 'FCN vs GCN Model Accuracy - fmri filtered only', figsize=(9,7))  
ax2 = df2.plot(kind='scatter', x="block_duration", y='GCN_1st_order', color='orange', ax=ax1)  
ax3 = df2.plot(kind='scatter', x="block_duration", y='GCN_5th_order', color='g', ax=ax1)
ax3 = df2.plot(kind='scatter', x="block_duration", y='GCN_8th_order', color='r', ax=ax1)
ax4 = df2.plot(x="block_duration", y=column_names, linestyle='dashed', ax = ax1);
ax4.set_ylabel("Model Accuracy")
# Out:
# Text(0, 0.5, 'Model Accuracy')

# %% [markdown]
# #### Imports

# %%
import os
import sys
import math
import time
import datetime

import numpy as np
import pandas as pd
import scipy.io

import nibabel as nib
from scipy import sparse
from scipy.stats import spearmanr
from sklearn import preprocessing, metrics,manifold
from sklearn.model_selection import cross_val_score, train_test_split,ShuffleSplit
import itertools


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

from util_funcs import *
from model import *

import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action='once')
#%load_ext autoreload #%autoreload #%reload_ext autoreload #import sys #reload(sys)

#imports
#pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.7.0+cu102.html

#CPU
device = torch.device("cpu")
print(device)
# Out:
# cpu

# %%
#Plot params
MEDIUM_SIZE = 14
BIGGER_SIZE = 17
plt.rc('font', size=MEDIUM_SIZE);
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
# Out:
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### 1. Data - fmri data <a class="anchor" id="data"></a>

# %%
#fmri
root_pth = '/camcan/schaefer_parc/'
task_type = 'Rest'
fmri_movie, subj_list = get_fmri_data(root_pth, task_type)
print(np.array(fmri_movie).shape) #(193, 400)
print(len(subj_list)) #644 subjects
fmri_movie_copy = fmri_movie.copy()
# Out:
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (644, 261, 400)
# 644

# %% [markdown]
# ##### Reduce num of time points

# %%
fmri2 = fmri[:,:193,400]
fmri2.shape

# %%
#Adjacency matrix 
root_pth = '/camcan/schaefer_parc/'
adj_mat = get_rsfmri_adj_matrix(root_pth)
#plot_corr_matrix(adj_mat)
# Out:
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# ...
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems

# %%
np.min(adj_mat)

# %%
#Adjacency matrix
adj_mat = Adjacency_matrix(adj_mat, n_neighbours = 8).get_adj_sp_torch_tensor()
adj_mat
# Out:
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# tensor(indices=tensor([[  1,   2,   3,  ..., 396, 397, 398],
#                        [  0,   0,   0,  ..., 399, 399, 399]]),
#        values=tensor([0.3348, 0.4519, 0.3895,  ..., 0.4030, 0.5090, 0.3403]),
#        size=(400, 400), nnz=4198, layout=torch.sparse_coo)

# %%
#Params
TR = 2.47
n_subjects = np.array(fmri_movie).shape[0]
print(f'N subjects = {n_subjects}')
n_regions = np.array(fmri_movie).shape[2]
# Out:
# N subjects = 644

# %%
#Specify block duration
block_duration = 16 #8 #16 #6 8 -Factor of 192 
total_time = fmri_movie.shape[1]
n_blocks = total_time // block_duration
n_labels = n_blocks
print(f'Number of blocks = {n_blocks}')
total_time = block_duration*n_blocks #Rounded number 
print(f'Total time = {total_time}')
# Out:
# Number of blocks = 16
# Total time = 256

# %% [markdown]
# ### 2.  Inspect data <a class="anchor" id="inspect_data"></a>

# %%
#Original - Plot x1 subject -1st ROI
subj_num = 1; ROI_num = 1;
fmri_1 = np.array(fmri_movie)[subj_num,:,ROI_num]
print(fmri_1.shape)
idx = range(0, len(fmri_1))
plt.plot(idx, fmri_1)
# Out:
# (261,)

# %% [markdown]
# ##### Normalised data

# %%
#Normalise
scaler = preprocessing.StandardScaler()
fmri_norm_1 = np.expand_dims(fmri_1, axis = 0).T
print(fmri_norm_1.shape)
fmri_norm_1 = scaler.fit_transform(fmri_norm_1)
plt.plot(idx, fmri_norm_1)
#plt.plot(idx, fmri_data_roi1[0,:])
# Out:
# (193, 1)
# /home/hannahcraddock/anaconda3/envs/hannah_env/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ##### Filtered data

# %%
#### Detrend data
fmri_filtered = nilearn.signal.clean(np.array(fmri_movie_copy)[1,:,:], sessions=None, detrend=True, 
                                       standardize='psc', confounds=None, low_pass=0.1, 
                                       high_pass=0.01, t_r=0.392, ensure_finite=False)
print(np.array(fmri_filtered).shape)
# Out:
# (193, 400)

# %%
#Filter
fmri_filtered1 = nilearn.signal.clean(fmri_norm_1, sessions=None, detrend=True, 
                                       standardize='zscore', confounds=None, low_pass=0.1, 
                                       high_pass=0.01, t_r= TR, ensure_finite=False)
#Plot
plt.plot(idx, fmri_filtered1)

# %% [markdown]
# ## 3. Filtered + Normalised Data <a class="anchor" id="filter_norm"></a>

# %%
def filter_fmri(fmri, standardize):  
    'filter fmri signal'
    
    #fmri
    fmri_filtered = []
    for subj in np.arange(0, fmri_movie_copy.shape[0]):
        fmri_subj = fmri_movie_copy[subj]
        filtered = nilearn.signal.clean(fmri_subj, sessions= None, detrend=True, 
                               standardize= False, confounds=None, low_pass= 0.1, 
                               high_pass= 0.01, t_r = TR, ensure_finite=False)
        fmri_filtered.append(filtered)
    
    return fmri_filtered

# %%
#Apply
standardize =  'zscore' #'psc', False
fmri_filtered = filter_fmri(fmri_movie_copy, standardize)
print(np.array(fmri_filtered).shape)
# Out:
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:204: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if not std < np.finfo(np.float).eps:
# (644, 261, 400)

# %% [markdown]
# ### 3.1  Dataloader (Train & Test sets) <a class="anchor" id="data_loader"></a>

# %%
#Split into train and test 
params = {'batch_size': 2, 
          'shuffle': True,
          'num_workers': 2}

test_size = 0.2
randomseed= 12345
rs = np.random.RandomState(randomseed)
#Training/Test indices
train_idx, test_idx = train_test_split(range(n_subjects), test_size = test_size, random_state=rs, shuffle=True)
print('Training on %d subjects, Testing on %d subjects' % (len(train_idx), len(test_idx)))
# Out:
# Training on 515 subjects, Testing on 129 subjects

# %%
#Train set
print(f'Block duration = {block_duration}')
fmri_data_train = [fmri_filtered[i] for i in train_idx] #Training subjects 
print(np.array(fmri_data_train).shape)
fmri_train = Fmri_dataset(fmri_data_train, TR, block_duration)
train_loader = DataLoader(fmri_train, collate_fn = fmri_samples_collate_fn, **params)

#Test set
fmri_data_test = [fmri_filtered[i] for i in test_idx]
print(np.array(fmri_data_test).shape)
fmri_test = Fmri_dataset(fmri_data_test, TR, block_duration)
test_loader = DataLoader(fmri_test, collate_fn=fmri_samples_collate_fn, **params)
# Out:
# Block duration = 16
# (515, 261, 400)
# (129, 261, 400)

# %% [markdown]
# ### 3.2 FCN <a class="anchor" id="fcn"></a>
#
# - Data = Filtered + Normalised

# %% [markdown]
# ##### Block duration = 6*TR

# %%
#Block duration
print(f'Block duration = {block_duration}')

#Define model 
model = FCN(n_regions, n_labels) #time points == x, regions == rows 
model = model.to(device)
print(model)
print("{} paramters to be trained in the model\n".format(count_parameters(model)))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
loss_func = nn.CrossEntropyLoss()
num_epochs=10
#adj_mat = 'a'

model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 6
# FCN(
#   (linear): Linear(in_features=400, out_features=128, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=32, out_features=43, bias=True)
#   )
# )
# 56875 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:1.553898 | Training Loss 0.043069 | Acc 0.043667
# Test Loss 0.042325 | Acc 0.065080
# Model updated: Best-Acc = 0.065080
#
# Epoch 1:
# Time Usage:1.590400 | Training Loss 0.041676 | Acc 0.063265
# Test Loss 0.040805 | Acc 0.080224
# Model updated: Best-Acc = 0.080224
#
# Epoch 2:
# Time Usage:1.586936 | Training Loss 0.041180 | Acc 0.072432
# Test Loss 0.040528 | Acc 0.084370
# Model updated: Best-Acc = 0.084370
#
# Epoch 3:
# Time Usage:1.541501 | Training Loss 0.040856 | Acc 0.077760
# Test Loss 0.040479 | Acc 0.087435
# Model updated: Best-Acc = 0.087435
#
# Epoch 4:
# Time Usage:1.612553 | Training Loss 0.040449 | Acc 0.081599
# Test Loss 0.040103 | Acc 0.096268
# Model updated: Best-Acc = 0.096268
#
# Epoch 5:
# Time Usage:1.565759 | Training Loss 0.040246 | Acc 0.085211
# Test Loss 0.039876 | Acc 0.093925
#
# Epoch 6:
# Time Usage:1.569801 | Training Loss 0.040139 | Acc 0.088914
# Test Loss 0.039788 | Acc 0.096088
#
# Epoch 7:
# Time Usage:1.590590 | Training Loss 0.040103 | Acc 0.089998
# Test Loss 0.039812 | Acc 0.108888
# Model updated: Best-Acc = 0.108888
#
# Epoch 8:
# Time Usage:1.538784 | Training Loss 0.039927 | Acc 0.093520
# Test Loss 0.039873 | Acc 0.107445
#
# Epoch 9:
# Time Usage:1.535982 | Training Loss 0.039825 | Acc 0.092888
# Test Loss 0.039544 | Acc 0.102217
# best testing accuarcy: 0.10888768703803858
# 0.10888768703803858

# %% [markdown]
# ##### Block duration = 8*TR

# %%
#CPU
print(f'Block duration = {block_duration}')

#Define model 
model = FCN(n_regions, n_labels) #time points == x, regions == rows 
model = model.to(device)
print(model)
print("{} paramters to be trained in the model\n".format(count_parameters(model)))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
#adj_mat = 'a'

model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# cpu
# FCN(
#   (linear): Linear(in_features=400, out_features=128, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 56248 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:2.089743 | Training Loss 0.047025 | Acc 0.332201
# Test Loss 0.026241 | Acc 0.721899
# Model updated: Best-Acc = 0.721899
#
# Epoch 1:
# Time Usage:1.940850 | Training Loss 0.029784 | Acc 0.581068
# Test Loss 0.018509 | Acc 0.802649
# Model updated: Best-Acc = 0.802649
#
# Epoch 2:
# Time Usage:2.073427 | Training Loss 0.024740 | Acc 0.653155
# Test Loss 0.014441 | Acc 0.837855
# Model updated: Best-Acc = 0.837855
#
# Epoch 3:
# Time Usage:1.983021 | Training Loss 0.020553 | Acc 0.708657
# Test Loss 0.016949 | Acc 0.796835
#
# Epoch 4:
# Time Usage:2.076088 | Training Loss 0.019066 | Acc 0.736408
# Test Loss 0.012225 | Acc 0.859496
# Model updated: Best-Acc = 0.859496
#
# Epoch 5:
# Time Usage:2.132248 | Training Loss 0.017133 | Acc 0.760518
# Test Loss 0.011416 | Acc 0.866279
# Model updated: Best-Acc = 0.866279
#
# Epoch 6:
# Time Usage:2.113567 | Training Loss 0.016556 | Acc 0.767880
# Test Loss 0.011798 | Acc 0.865633
#
# Epoch 7:
# Time Usage:2.102252 | Training Loss 0.016673 | Acc 0.770146
# Test Loss 0.012973 | Acc 0.861434
#
# Epoch 8:
# Time Usage:2.052160 | Training Loss 0.015143 | Acc 0.776294
# Test Loss 0.010321 | Acc 0.883075
# Model updated: Best-Acc = 0.883075
#
# Epoch 9:
# Time Usage:2.143685 | Training Loss 0.014217 | Acc 0.792880
# Test Loss 0.010013 | Acc 0.892442
# Model updated: Best-Acc = 0.892442
# best testing accuarcy: 0.8924418604651163
# 0.8924418604651163

# %% [markdown]
# ##### Block duration = 16*TR

# %%
print(f'Block duration = {block_duration}')

#CPU
device = torch.device("cpu")
print(device)

#Define model 
model = FCN(n_regions, n_labels) #time points == x, regions == rows 
model = model.to(device)
print(model)
print("{} paramters to be trained in the model\n".format(count_parameters(model)))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
loss_func = nn.CrossEntropyLoss()
num_epochs=10
#adj_mat = 'a'

model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# cpu
# FCN(
#   (linear): Linear(in_features=400, out_features=128, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#   )
# )
# 55984 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:1.304915 | Training Loss 0.081308 | Acc 0.152791
# Test Loss 0.076000 | Acc 0.206395
# Model updated: Best-Acc = 0.206395
#
# Epoch 1:
# Time Usage:1.266533 | Training Loss 0.076037 | Acc 0.203398
# Test Loss 0.072592 | Acc 0.226744
# Model updated: Best-Acc = 0.226744
#
# Epoch 2:
# Time Usage:1.292430 | Training Loss 0.073971 | Acc 0.218568
# Test Loss 0.071739 | Acc 0.246124
# Model updated: Best-Acc = 0.246124
#
# Epoch 3:
# Time Usage:1.306630 | Training Loss 0.072465 | Acc 0.229005
# Test Loss 0.070681 | Acc 0.248062
# Model updated: Best-Acc = 0.248062
#
# Epoch 4:
# Time Usage:1.324821 | Training Loss 0.071961 | Acc 0.232646
# Test Loss 0.070518 | Acc 0.243217
#
# Epoch 5:
# Time Usage:1.274328 | Training Loss 0.071069 | Acc 0.241748
# Test Loss 0.070406 | Acc 0.261143
# Model updated: Best-Acc = 0.261143
#
# Epoch 6:
# Time Usage:1.248327 | Training Loss 0.070969 | Acc 0.238835
# Test Loss 0.070522 | Acc 0.257267
#
# Epoch 7:
# Time Usage:1.301929 | Training Loss 0.070172 | Acc 0.239563
# Test Loss 0.069690 | Acc 0.256298
#
# Epoch 8:
# Time Usage:1.295961 | Training Loss 0.070237 | Acc 0.242718
# Test Loss 0.073377 | Acc 0.228682
#
# Epoch 9:
# Time Usage:1.251476 | Training Loss 0.070180 | Acc 0.242112
# Test Loss 0.069779 | Acc 0.257752
# best testing accuarcy: 0.2611434108527132
# 0.2611434108527132

# %% [markdown]
# ### 2. GCN <a class="anchor" id="gcn"></a>

# %% [markdown]
# ##### Block duration = 6*TR
# - __First Order__

# %%
from model import ChebNet

print(f'Block duration = {block_duration}')
#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 6
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (6 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=43, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=43, bias=True)
#   )
# )
# 69614 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:316.793594 | Training Loss 0.043401 | Acc 0.031881
# Test Loss 0.042899 | Acc 0.050658
# Model updated: Best-Acc = 0.050658
#
# Epoch 1:
# Time Usage:318.665421 | Training Loss 0.042559 | Acc 0.051208
# Test Loss 0.042482 | Acc 0.053542
# Model updated: Best-Acc = 0.053542
#
# Epoch 2:
# Time Usage:316.658476 | Training Loss 0.042322 | Acc 0.056717
# Test Loss 0.042243 | Acc 0.070308
# Model updated: Best-Acc = 0.070308
#
# Epoch 3:
# Time Usage:318.523816 | Training Loss 0.042051 | Acc 0.063852
# Test Loss 0.041848 | Acc 0.081846
# Model updated: Best-Acc = 0.081846
#
# Epoch 4:
# Time Usage:319.173293 | Training Loss 0.041845 | Acc 0.073832
# Test Loss 0.041836 | Acc 0.085452
# Model updated: Best-Acc = 0.085452
#
# Epoch 5:
# Time Usage:314.806778 | Training Loss 0.041680 | Acc 0.077083
# Test Loss 0.041658 | Acc 0.086894
# Model updated: Best-Acc = 0.086894
#
# Epoch 6:
# Time Usage:313.093616 | Training Loss 0.041552 | Acc 0.079160
# Test Loss 0.041400 | Acc 0.092122
# Model updated: Best-Acc = 0.092122
#
# Epoch 7:
# Time Usage:316.251683 | Training Loss 0.041504 | Acc 0.079928
# Test Loss 0.041402 | Acc 0.093384
# Model updated: Best-Acc = 0.093384
#
# Epoch 8:
# Time Usage:318.960481 | Training Loss 0.041397 | Acc 0.081824
# Test Loss 0.041093 | Acc 0.095908
# Model updated: Best-Acc = 0.095908
#
# Epoch 9:
# Time Usage:319.504380 | Training Loss 0.041291 | Acc 0.085256
# Test Loss 0.041266 | Acc 0.098792
# Model updated: Best-Acc = 0.098792
# best testing accuarcy: 0.09879213989543897
# 0.09879213989543897

# %% [markdown]
# #### GCN - expanding to k-th order neighborhood (connecting by k steps)

# %% [markdown]
# #### Block duration = 6

# %% [markdown]
# - Fifth Order K = 5

# %%
#Model params 
k_order = 5
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 6
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(6, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=43, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=43, bias=True)
#   )
# )
# 80814 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:1336.549748 | Training Loss 0.043584 | Acc 0.034455
# Test Loss 0.043057 | Acc 0.045610
# Model updated: Best-Acc = 0.045610
#
# Epoch 1:
# Time Usage:1327.818110 | Training Loss 0.043437 | Acc 0.033868
# Test Loss 0.043053 | Acc 0.047052
# Model updated: Best-Acc = 0.047052
#
# Epoch 2:
# Time Usage:1328.000757 | Training Loss 0.042826 | Acc 0.044570
# Test Loss 0.042947 | Acc 0.046692
#
# Epoch 3:
# Time Usage:1334.913745 | Training Loss 0.042745 | Acc 0.047144
# Test Loss 0.042905 | Acc 0.047593
# Model updated: Best-Acc = 0.047593
#
# Epoch 4:
# Time Usage:1325.494615 | Training Loss 0.042666 | Acc 0.047776
# Test Loss 0.042855 | Acc 0.046331
#
# Epoch 5:
# Time Usage:1337.461292 | Training Loss 0.042623 | Acc 0.046331
# Test Loss 0.042836 | Acc 0.046331
#
# Epoch 6:
# Time Usage:1343.193659 | Training Loss 0.043352 | Acc 0.034319
# Test Loss 0.044156 | Acc 0.023256
#
# Epoch 7:
# Time Usage:1358.548213 | Training Loss 0.043870 | Acc 0.024520
# Test Loss 0.044100 | Acc 0.023256
#
# Epoch 8:
# Time Usage:1359.055999 | Training Loss 0.043836 | Acc 0.023617
# Test Loss 0.044081 | Acc 0.023256
#
# Epoch 9:
# Time Usage:1357.475036 | Training Loss 0.043824 | Acc 0.024023
# Test Loss 0.044076 | Acc 0.023256
# best testing accuarcy: 0.047593293672255274
# 0.047593293672255274

# %% [markdown]
# __K = 8__

# %%
#Model params 
k_order = 8
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K= k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 6
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(6, 32, K=8)
#     (1): ChebConv(32, 32, K=8)
#     (2): ChebConv(32, 32, K=8)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=43, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=43, bias=True)
#   )
# )
# 87534 paramters to be trained in the model
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-eae289746034> in <module>
#      16 optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)
#      17
# ---> 18 model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
#
# ~/Graphical_Neural_Networks/model.py in model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
#     465     model_history['test_acc']=[];
#     466     for epoch in range(num_epochs):
# --> 467         train_loss, train_acc = train(model,adj_mat, device, train_loader, optimizer,loss_func, epoch)
#     468         model_history['train_loss'].append(train_loss)
#     469         model_history['train_acc'].append(train_acc)
#
# ~/Graphical_Neural_Networks/model.py in train(model, adj_mat, device, train_loader, optimizer, loss_func, epoch)
#     402
#     403         optimizer.zero_grad()
# --> 404         out = model(data, adj_mat)
#     405         loss = loss_func(out,target)
#     406         pred = F.log_softmax(out, dim=1).argmax(dim=1)
#
# ~/anaconda3/envs/env_python38/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/Graphical_Neural_Networks/model.py in forward(self, inputs, adj_mat)
#     157
#     158     def forward(self, inputs, adj_mat):
# --> 159         edge_index = adj_mat._indices()
#     160         edge_weight = adj_mat._values()
#     161         batch = inputs.size(0)
#
# AttributeError: 'numpy.ndarray' object has no attribute '_indices'

# %% [markdown]
# ##### Block duration = 16*TR
# - First order

# %%
from model import ChebNet

print(f'Block duration = {block_duration}')
#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (16 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=16, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=16, bias=True)
#   )
# )
# 59296 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:102.417664 | Training Loss 0.087129 | Acc 0.064320
# Test Loss 0.087317 | Acc 0.062500
# Model updated: Best-Acc = 0.062500
#
# Epoch 1:
# Time Usage:101.573582 | Training Loss 0.086832 | Acc 0.062015
# Test Loss 0.087314 | Acc 0.061531
#
# Epoch 2:
# Time Usage:101.800530 | Training Loss 0.086828 | Acc 0.062015
# Test Loss 0.087315 | Acc 0.062500
#
# Epoch 3:
# Time Usage:96.336508 | Training Loss 0.086814 | Acc 0.062136
# Test Loss 0.087315 | Acc 0.062500
#
# Epoch 4:
# Time Usage:101.224883 | Training Loss 0.086812 | Acc 0.062379
# Test Loss 0.086953 | Acc 0.112403
# Model updated: Best-Acc = 0.112403
#
# Epoch 5:
# Time Usage:102.908479 | Training Loss 0.083241 | Acc 0.126092
# Test Loss 0.079144 | Acc 0.178779
# Model updated: Best-Acc = 0.178779
#
# Epoch 6:
# Time Usage:102.587704 | Training Loss 0.078473 | Acc 0.174272
# Test Loss 0.076945 | Acc 0.181202
# Model updated: Best-Acc = 0.181202
#
# Epoch 7:
# Time Usage:102.442360 | Training Loss 0.077254 | Acc 0.185680
# Test Loss 0.076850 | Acc 0.203004
# Model updated: Best-Acc = 0.203004
#
# Epoch 8:
# Time Usage:102.752942 | Training Loss 0.076521 | Acc 0.185922
# Test Loss 0.075723 | Acc 0.209787
# Model updated: Best-Acc = 0.209787
#
# Epoch 9:
# Time Usage:101.698473 | Training Loss 0.076201 | Acc 0.195267
# Test Loss 0.075552 | Acc 0.220446
# Model updated: Best-Acc = 0.220446
# best testing accuarcy: 0.22044573643410853
# 0.22044573643410853

# %% [markdown]
# #### GCN - expanding to k-th order neighborhood (connecting by k steps)

# %% [markdown]
# __K = 5__

# %%
#Model params 
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=5, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(16, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=16, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=16, bias=True)
#   )
# )
# 72096 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:338.398487 | Training Loss 0.083512 | Acc 0.112864
# Test Loss 0.081673 | Acc 0.121124
# Model updated: Best-Acc = 0.121124
#
# Epoch 1:
# Time Usage:337.466105 | Training Loss 0.081350 | Acc 0.124150
# Test Loss 0.081139 | Acc 0.123547
# Model updated: Best-Acc = 0.123547
#
# Epoch 2:
# Time Usage:336.533126 | Training Loss 0.081154 | Acc 0.119175
# Test Loss 0.080637 | Acc 0.129360
# Model updated: Best-Acc = 0.129360
#
# Epoch 3:
# Time Usage:335.647372 | Training Loss 0.080633 | Acc 0.124515
# Test Loss 0.080345 | Acc 0.125969
#
# Epoch 4:
# Time Usage:334.467025 | Training Loss 0.080472 | Acc 0.120146
# Test Loss 0.080792 | Acc 0.121609
#
# Epoch 5:
# Time Usage:338.709459 | Training Loss 0.080264 | Acc 0.125364
# Test Loss 0.080322 | Acc 0.126453
#
# Epoch 6:
# Time Usage:337.195322 | Training Loss 0.080649 | Acc 0.122087
# Test Loss 0.080430 | Acc 0.134205
# Model updated: Best-Acc = 0.134205
#
# Epoch 7:
# Time Usage:335.207657 | Training Loss 0.080415 | Acc 0.125364
# Test Loss 0.080398 | Acc 0.125969
#
# Epoch 8:
# Time Usage:337.833527 | Training Loss 0.079922 | Acc 0.124272
# Test Loss 0.080113 | Acc 0.125969
#
# Epoch 9:
# Time Usage:339.353139 | Training Loss 0.079988 | Acc 0.123058
# Test Loss 0.080069 | Acc 0.129360
# best testing accuarcy: 0.13420542635658914
# 0.13420542635658914

# %% [markdown]
# __K = 8__

# %%
#Model params 
k_order = 8
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K= k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(16, 32, K=8)
#     (1): ChebConv(32, 32, K=8)
#     (2): ChebConv(32, 32, K=8)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=12, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=12, bias=True)
#   )
# )
# 78200 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:309.104297 | Training Loss 0.101765 | Acc 0.140291
# Test Loss 0.086065 | Acc 0.299742
# Model updated: Best-Acc = 0.299742
#
# Epoch 1:
# Time Usage:305.677657 | Training Loss 0.081510 | Acc 0.313107
# Test Loss 0.072405 | Acc 0.447674
# Model updated: Best-Acc = 0.447674
#
# Epoch 2:
# Time Usage:307.734573 | Training Loss 0.071732 | Acc 0.401618
# Test Loss 0.067202 | Acc 0.501938
# Model updated: Best-Acc = 0.501938
#
# Epoch 3:
# Time Usage:309.135857 | Training Loss 0.063760 | Acc 0.479288
# Test Loss 0.059461 | Acc 0.607235
# Model updated: Best-Acc = 0.607235
#
# Epoch 4:
# Time Usage:310.854897 | Training Loss 0.055406 | Acc 0.562298
# Test Loss 0.048709 | Acc 0.683463
# Model updated: Best-Acc = 0.683463
#
# Epoch 5:
# Time Usage:310.298045 | Training Loss 0.049258 | Acc 0.621197
# Test Loss 0.044579 | Acc 0.729328
# Model updated: Best-Acc = 0.729328
#
# Epoch 6:
# Time Usage:310.497993 | Training Loss 0.042052 | Acc 0.679935
# Test Loss 0.043154 | Acc 0.762274
# Model updated: Best-Acc = 0.762274
#
# Epoch 7:
# Time Usage:313.653706 | Training Loss 0.039909 | Acc 0.703074
# Test Loss 0.036135 | Acc 0.795220
# Model updated: Best-Acc = 0.795220
#
# Epoch 8:
# Time Usage:313.705451 | Training Loss 0.036863 | Acc 0.734628
# Test Loss 0.031445 | Acc 0.795220
#
# Epoch 9:
# Time Usage:313.005179 | Training Loss 0.034211 | Acc 0.751456
# Test Loss 0.027517 | Acc 0.828811
# Model updated: Best-Acc = 0.828811
# best testing accuarcy: 0.8288113695090439
# 0.8288113695090439

# %% [markdown]
# ##### Block duration = 8*TR
# - First order

# %%
from model import ChebNet

print(f'Block duration = {block_duration}')
#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (8 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 62192 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:136.866987 | Training Loss 0.064037 | Acc 0.084790
# Test Loss 0.057415 | Acc 0.196705
# Model updated: Best-Acc = 0.196705
#
# Epoch 1:
# Time Usage:136.333657 | Training Loss 0.053554 | Acc 0.214887
# Test Loss 0.048254 | Acc 0.322674
# Model updated: Best-Acc = 0.322674
#
# Epoch 2:
# Time Usage:136.277246 | Training Loss 0.047754 | Acc 0.287702
# Test Loss 0.043124 | Acc 0.381783
# Model updated: Best-Acc = 0.381783
#
# Epoch 3:
# Time Usage:136.923594 | Training Loss 0.045947 | Acc 0.303236
# Test Loss 0.041699 | Acc 0.418605
# Model updated: Best-Acc = 0.418605
#
# Epoch 4:
# Time Usage:136.191245 | Training Loss 0.043657 | Acc 0.331230
# Test Loss 0.038679 | Acc 0.445413
# Model updated: Best-Acc = 0.445413
#
# Epoch 5:
# Time Usage:136.219376 | Training Loss 0.042057 | Acc 0.348786
# Test Loss 0.038809 | Acc 0.456072
# Model updated: Best-Acc = 0.456072
#
# Epoch 6:
# Time Usage:136.997657 | Training Loss 0.041643 | Acc 0.360680
# Test Loss 0.037164 | Acc 0.488372
# Model updated: Best-Acc = 0.488372
#
# Epoch 7:
# Time Usage:137.639931 | Training Loss 0.040238 | Acc 0.382201
# Test Loss 0.036269 | Acc 0.487726
#
# Epoch 8:
# Time Usage:137.690120 | Training Loss 0.038907 | Acc 0.398058
# Test Loss 0.035634 | Acc 0.509690
# Model updated: Best-Acc = 0.509690
#
# Epoch 9:
# Time Usage:137.668896 | Training Loss 0.039634 | Acc 0.387783
# Test Loss 0.035046 | Acc 0.499031
# best testing accuarcy: 0.5096899224806202
# 0.5096899224806202

# %% [markdown]
# #### GCN - expanding to k-th order neighborhood (connecting by k steps)

# %% [markdown]
# __K = 5__

# %%
#Model params 
k_order = 5
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(8, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 73712 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:461.768672 | Training Loss 0.063813 | Acc 0.096359
# Test Loss 0.056611 | Acc 0.254199
# Model updated: Best-Acc = 0.254199
#
# Epoch 1:
# Time Usage:462.501058 | Training Loss 0.053143 | Acc 0.233900
# Test Loss 0.044483 | Acc 0.389858
# Model updated: Best-Acc = 0.389858
#
# Epoch 2:
# Time Usage:463.215743 | Training Loss 0.045467 | Acc 0.327184
# Test Loss 0.040119 | Acc 0.468992
# Model updated: Best-Acc = 0.468992
#
# Epoch 3:
# Time Usage:458.726424 | Training Loss 0.038766 | Acc 0.416019
# Test Loss 0.032912 | Acc 0.602713
# Model updated: Best-Acc = 0.602713
#
# Epoch 4:
# Time Usage:462.504014 | Training Loss 0.034784 | Acc 0.475000
# Test Loss 0.028947 | Acc 0.660853
# Model updated: Best-Acc = 0.660853
#
# Epoch 5:
# Time Usage:462.674812 | Training Loss 0.031720 | Acc 0.533010
# Test Loss 0.026697 | Acc 0.691537
# Model updated: Best-Acc = 0.691537
#
# Epoch 6:
# Time Usage:463.343089 | Training Loss 0.029103 | Acc 0.572249
# Test Loss 0.022716 | Acc 0.753230
# Model updated: Best-Acc = 0.753230
#
# Epoch 7:
# Time Usage:463.317412 | Training Loss 0.026412 | Acc 0.621117
# Test Loss 0.022410 | Acc 0.765504
# Model updated: Best-Acc = 0.765504
#
# Epoch 8:
# Time Usage:463.881071 | Training Loss 0.024833 | Acc 0.647654
# Test Loss 0.020935 | Acc 0.776163
# Model updated: Best-Acc = 0.776163
#
# Epoch 9:
# Time Usage:468.758976 | Training Loss 0.022512 | Acc 0.683172
# Test Loss 0.017491 | Acc 0.825258
# Model updated: Best-Acc = 0.825258
# best testing accuarcy: 0.8252583979328165
# 0.8252583979328165

# %% [markdown]
# __K = 8__

# %%
#Model params 
k_order = 8
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K= k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(8, 32, K=8)
#     (1): ChebConv(32, 32, K=8)
#     (2): ChebConv(32, 32, K=8)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 80624 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:741.675057 | Training Loss 0.066621 | Acc 0.049272
# Test Loss 0.065641 | Acc 0.086886
# Model updated: Best-Acc = 0.086886
#
# Epoch 1:
# Time Usage:747.862950 | Training Loss 0.061434 | Acc 0.142071
# Test Loss 0.056878 | Acc 0.290052
# Model updated: Best-Acc = 0.290052
#
# Epoch 2:
# Time Usage:740.443576 | Training Loss 0.050903 | Acc 0.252427
# Test Loss 0.047135 | Acc 0.439276
# Model updated: Best-Acc = 0.439276
#
# Epoch 3:
# Time Usage:736.207062 | Training Loss 0.043404 | Acc 0.351375
# Test Loss 0.040763 | Acc 0.509367
# Model updated: Best-Acc = 0.509367
#
# Epoch 4:
# Time Usage:740.879949 | Training Loss 0.038792 | Acc 0.418770
# Test Loss 0.040318 | Acc 0.525840
# Model updated: Best-Acc = 0.525840
#
# Epoch 5:
# Time Usage:739.785724 | Training Loss 0.035091 | Acc 0.481230
# Test Loss 0.032940 | Acc 0.650194
# Model updated: Best-Acc = 0.650194
#
# Epoch 6:
# Time Usage:742.189692 | Training Loss 0.032587 | Acc 0.520712
# Test Loss 0.027018 | Acc 0.688307
# Model updated: Best-Acc = 0.688307
#
# Epoch 7:
# Time Usage:746.991251 | Training Loss 0.030446 | Acc 0.561327
# Test Loss 0.029565 | Acc 0.686693
#
# Epoch 8:
# Time Usage:738.504085 | Training Loss 0.028577 | Acc 0.591748
# Test Loss 0.024133 | Acc 0.760013
# Model updated: Best-Acc = 0.760013
#
# Epoch 9:
# Time Usage:740.818838 | Training Loss 0.026504 | Acc 0.628803
# Test Loss 0.023167 | Acc 0.770349
# Model updated: Best-Acc = 0.770349
# best testing accuarcy: 0.7703488372093024
# 0.7703488372093024

# %% [markdown]
# ## 4. Filtered + non-standardised data <a class="anchor" id="filter"></a>

# %%
def filter_fmri(fmri, standardize):  
    'filter fmri signal'
    
    #fmri
    fmri_filtered = []
    for subj in np.arange(0, fmri_movie_copy.shape[0]):
        fmri_subj = fmri_movie_copy[subj]
        filtered = nilearn.signal.clean(fmri_subj, sessions= None, detrend=True, 
                               standardize= False, confounds=None, low_pass= 0.1, 
                               high_pass= 0.01, t_r = TR, ensure_finite=False)
        fmri_filtered.append(filtered)
    
    return fmri_filtered

# %%
#Apply
standardize =  False #'psc', 'zscore'
fmri_filtered2 = filter_fmri(fmri_movie_copy, standardize)
print(np.array(fmri_filtered2).shape)

# %% [markdown]
# ### 4.1  Dataloader (Train & Test sets) <a class="anchor" id="data_loader2"></a>

# %%
#Split into train and test 
params = {'batch_size': 2, 
          'shuffle': True,
          'num_workers': 2}

test_size = 0.2
randomseed= 12345
rs = np.random.RandomState(randomseed)
#Training/Test indices
train_idx, test_idx = train_test_split(range(n_subjects), test_size = test_size, random_state=rs, shuffle=True)
print('Training on %d subjects, Testing on %d subjects' % (len(train_idx), len(test_idx)))
# Out:
# Training on 515 subjects, Testing on 129 subjects

# %%
#Train set
print(f'Block duration = {block_duration}')
fmri_data_train = [fmri_filtered2[i] for i in train_idx] #Training subjects 
print(np.array(fmri_data_train).shape)
fmri_train = Fmri_dataset(fmri_data_train, TR, block_duration)
train_loader = DataLoader(fmri_train, collate_fn = fmri_samples_collate_fn, **params)

#Test set
fmri_data_test = [fmri_filtered2[i] for i in test_idx]
print(np.array(fmri_data_test).shape)
fmri_test = Fmri_dataset(fmri_data_test, TR, block_duration)
test_loader = DataLoader(fmri_test, collate_fn=fmri_samples_collate_fn, **params)

# %% [markdown]
# ## 4.2 FCN <a class="anchor" id="fcn2"></a>

# %% [markdown]
# ##### Block duration = 6*TR

# %%
#Block duration
print(f'Block duration = {block_duration}')

#Define model 
model = FCN(n_regions, n_labels) #time points == x, regions == rows 
model = model.to(device)
print(model)
print("{} paramters to be trained in the model\n".format(count_parameters(model)))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
loss_func = nn.CrossEntropyLoss()
num_epochs=10
#adj_mat = 'a'

model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)

# %% [markdown]
# ##### Block duration = 16*TR

# %%
#Block duration
print(f'Block duration = {block_duration}')

#Define model 
model = FCN(n_regions, n_labels) #time points == x, regions == rows 
model = model.to(device)
print(model)
print("{} paramters to be trained in the model\n".format(count_parameters(model)))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
loss_func = nn.CrossEntropyLoss()
num_epochs=10
#adj_mat = 'a'

model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# FCN(
#   (linear): Linear(in_features=400, out_features=128, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#   )
# )
# 55984 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:1.323977 | Training Loss 0.080751 | Acc 0.155461
# Test Loss 0.075643 | Acc 0.184109
# Model updated: Best-Acc = 0.184109
#
# Epoch 1:
# Time Usage:1.250524 | Training Loss 0.075729 | Acc 0.195024
# Test Loss 0.072756 | Acc 0.234496
# Model updated: Best-Acc = 0.234496
#
# Epoch 2:
# Time Usage:1.273951 | Training Loss 0.073959 | Acc 0.215898
# Test Loss 0.071607 | Acc 0.245155
# Model updated: Best-Acc = 0.245155
#
# Epoch 3:
# Time Usage:1.286131 | Training Loss 0.072567 | Acc 0.230947
# Test Loss 0.071610 | Acc 0.232074
#
# Epoch 4:
# Time Usage:1.221655 | Training Loss 0.071748 | Acc 0.231675
# Test Loss 0.070362 | Acc 0.250000
# Model updated: Best-Acc = 0.250000
#
# Epoch 5:
# Time Usage:1.311050 | Training Loss 0.070942 | Acc 0.242476
# Test Loss 0.070090 | Acc 0.251938
# Model updated: Best-Acc = 0.251938
#
# Epoch 6:
# Time Usage:1.287974 | Training Loss 0.070653 | Acc 0.238107
# Test Loss 0.069852 | Acc 0.243702
#
# Epoch 7:
# Time Usage:1.299037 | Training Loss 0.070402 | Acc 0.241748
# Test Loss 0.069615 | Acc 0.245155
#
# Epoch 8:
# Time Usage:1.320762 | Training Loss 0.070176 | Acc 0.238228
# Test Loss 0.070058 | Acc 0.241279
#
# Epoch 9:
# Time Usage:1.323169 | Training Loss 0.069722 | Acc 0.250728
# Test Loss 0.069631 | Acc 0.261628
# Model updated: Best-Acc = 0.261628
# best testing accuarcy: 0.2616279069767442
# 0.2616279069767442

# %% [markdown]
# ### 4.3. GCN <a class="anchor" id="gcn2"></a>
# - First order

# %% [markdown]
# ##### Block duration = 6*TR

# %%
from model import ChebNet
print(f'Block duration = {block_duration}')

#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)

# %% [markdown]
# ##### Block duration = 8*TR

# %%
from model import ChebNet
print(f'Block duration = {block_duration}')

#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (8 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 62192 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:136.669055 | Training Loss 0.064165 | Acc 0.080178
# Test Loss 0.057848 | Acc 0.188953
# Model updated: Best-Acc = 0.188953
#
# Epoch 1:
# Time Usage:136.768747 | Training Loss 0.053608 | Acc 0.203883
# Test Loss 0.047031 | Acc 0.354005
# Model updated: Best-Acc = 0.354005
#
# Epoch 2:
# Time Usage:136.665167 | Training Loss 0.048493 | Acc 0.274110
# Test Loss 0.043271 | Acc 0.409561
# Model updated: Best-Acc = 0.409561
#
# Epoch 3:
# Time Usage:137.119146 | Training Loss 0.044841 | Acc 0.314725
# Test Loss 0.040702 | Acc 0.442506
# Model updated: Best-Acc = 0.442506
#
# Epoch 4:
# Time Usage:136.771467 | Training Loss 0.042836 | Acc 0.347411
# Test Loss 0.037841 | Acc 0.474806
# Model updated: Best-Acc = 0.474806
#
# Epoch 5:
# Time Usage:136.918263 | Training Loss 0.041895 | Acc 0.358819
# Test Loss 0.037519 | Acc 0.486434
# Model updated: Best-Acc = 0.486434
#
# Epoch 6:
# Time Usage:136.508248 | Training Loss 0.040253 | Acc 0.383010
# Test Loss 0.037086 | Acc 0.492894
# Model updated: Best-Acc = 0.492894
#
# Epoch 7:
# Time Usage:136.707421 | Training Loss 0.039900 | Acc 0.385437
# Test Loss 0.036830 | Acc 0.460594
#
# Epoch 8:
# Time Usage:137.771631 | Training Loss 0.039562 | Acc 0.383576
# Test Loss 0.037112 | Acc 0.461886
#
# Epoch 9:
# Time Usage:138.796329 | Training Loss 0.039299 | Acc 0.392314
# Test Loss 0.034081 | Acc 0.525517
# Model updated: Best-Acc = 0.525517
# best testing accuarcy: 0.525516795865633
# 0.525516795865633

# %% [markdown]
# ##### Block duration = 16*TR

# %%
from model import ChebNet
print(f'Block duration = {block_duration}')

#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (16 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=16, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=16, bias=True)
#   )
# )
# 59296 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:102.530251 | Training Loss 0.087313 | Acc 0.065655
# Test Loss 0.087321 | Acc 0.062500
# Model updated: Best-Acc = 0.062500
#
# Epoch 1:
# Time Usage:102.899635 | Training Loss 0.086824 | Acc 0.062743
# Test Loss 0.087315 | Acc 0.062500
#
# Epoch 2:
# Time Usage:100.136777 | Training Loss 0.086838 | Acc 0.064320
# Test Loss 0.087315 | Acc 0.062500
#
# Epoch 3:
# Time Usage:102.365254 | Training Loss 0.086826 | Acc 0.063107
# Test Loss 0.087316 | Acc 0.062500
#
# Epoch 4:
# Time Usage:101.202150 | Training Loss 0.086717 | Acc 0.069660
# Test Loss 0.086259 | Acc 0.110950
# Model updated: Best-Acc = 0.110950
#
# Epoch 5:
# Time Usage:101.853143 | Training Loss 0.082510 | Acc 0.121117
# Test Loss 0.081004 | Acc 0.133721
# Model updated: Best-Acc = 0.133721
#
# Epoch 6:
# Time Usage:103.727266 | Training Loss 0.081217 | Acc 0.133495
# Test Loss 0.081033 | Acc 0.163275
# Model updated: Best-Acc = 0.163275
#
# Epoch 7:
# Time Usage:101.098075 | Training Loss 0.080105 | Acc 0.143689
# Test Loss 0.078914 | Acc 0.189438
# Model updated: Best-Acc = 0.189438
#
# Epoch 8:
# Time Usage:101.993846 | Training Loss 0.079272 | Acc 0.152670
# Test Loss 0.077369 | Acc 0.192829
# Model updated: Best-Acc = 0.192829
#
# Epoch 9:
# Time Usage:103.230237 | Training Loss 0.078327 | Acc 0.164199
# Test Loss 0.076631 | Acc 0.186047
# best testing accuarcy: 0.1928294573643411
# 0.1928294573643411

# %% [markdown]
# #### GCN - expanding to k-th order neighborhood (connecting by k steps)

# %% [markdown]
# ##### Block duration = 6*TR

# %%
#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=5, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)

# %% [markdown]
# ##### Block duration = 8*TR

# %%
#Model params 
k_order = 5
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(8, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 73712 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:462.142948 | Training Loss 0.066055 | Acc 0.053641
# Test Loss 0.063942 | Acc 0.129522
# Model updated: Best-Acc = 0.129522
#
# Epoch 1:
# Time Usage:466.012141 | Training Loss 0.059438 | Acc 0.141181
# Test Loss 0.053810 | Acc 0.273579
# Model updated: Best-Acc = 0.273579
#
# Epoch 2:
# Time Usage:463.764611 | Training Loss 0.052009 | Acc 0.241100
# Test Loss 0.051736 | Acc 0.305556
# Model updated: Best-Acc = 0.305556
#
# Epoch 3:
# Time Usage:462.816946 | Training Loss 0.045531 | Acc 0.330502
# Test Loss 0.042648 | Acc 0.509367
# Model updated: Best-Acc = 0.509367
#
# Epoch 4:
# Time Usage:462.266737 | Training Loss 0.039409 | Acc 0.424110
# Test Loss 0.038938 | Acc 0.577519
# Model updated: Best-Acc = 0.577519
#
# Epoch 5:
# Time Usage:464.974457 | Training Loss 0.035953 | Acc 0.483738
# Test Loss 0.028372 | Acc 0.687339
# Model updated: Best-Acc = 0.687339
#
# Epoch 6:
# Time Usage:463.229842 | Training Loss 0.032285 | Acc 0.541343
# Test Loss 0.027187 | Acc 0.727713
# Model updated: Best-Acc = 0.727713
#
# Epoch 7:
# Time Usage:462.996209 | Training Loss 0.030146 | Acc 0.574838
# Test Loss 0.026434 | Acc 0.735142
# Model updated: Best-Acc = 0.735142
#
# Epoch 8:
# Time Usage:465.005471 | Training Loss 0.028746 | Acc 0.596278
# Test Loss 0.023747 | Acc 0.767442
# Model updated: Best-Acc = 0.767442
#
# Epoch 9:
# Time Usage:465.777888 | Training Loss 0.027698 | Acc 0.617476
# Test Loss 0.023118 | Acc 0.770995
# Model updated: Best-Acc = 0.770995
# best testing accuarcy: 0.7709948320413437
# 0.7709948320413437

# %% [markdown]
# ##### Block duration = 16*TR

# %%
#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=5, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(16, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=16, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=16, bias=True)
#   )
# )
# 72096 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:338.331022 | Training Loss 0.085189 | Acc 0.091262
# Test Loss 0.080880 | Acc 0.132267
# Model updated: Best-Acc = 0.132267
#
# Epoch 1:
# Time Usage:339.163326 | Training Loss 0.082012 | Acc 0.126820
# Test Loss 0.079388 | Acc 0.153101
# Model updated: Best-Acc = 0.153101
#
# Epoch 2:
# Time Usage:341.140671 | Training Loss 0.080303 | Acc 0.139199
# Test Loss 0.080845 | Acc 0.131783
#
# Epoch 3:
# Time Usage:340.939362 | Training Loss 0.079396 | Acc 0.151092
# Test Loss 0.079504 | Acc 0.153585
# Model updated: Best-Acc = 0.153585
#
# Epoch 4:
# Time Usage:341.571662 | Training Loss 0.078847 | Acc 0.152427
# Test Loss 0.078353 | Acc 0.168605
# Model updated: Best-Acc = 0.168605
#
# Epoch 5:
# Time Usage:340.527577 | Training Loss 0.078641 | Acc 0.157160
# Test Loss 0.077492 | Acc 0.173934
# Model updated: Best-Acc = 0.173934
#
# Epoch 6:
# Time Usage:341.775688 | Training Loss 0.078192 | Acc 0.159830
# Test Loss 0.077608 | Acc 0.168605
#
# Epoch 7:
# Time Usage:340.606593 | Training Loss 0.078273 | Acc 0.161044
# Test Loss 0.078568 | Acc 0.162791
#
# Epoch 8:
# Time Usage:339.282678 | Training Loss 0.078384 | Acc 0.157524
# Test Loss 0.077192 | Acc 0.185562
# Model updated: Best-Acc = 0.185562
#
# Epoch 9:
# Time Usage:341.400286 | Training Loss 0.077577 | Acc 0.166383
# Test Loss 0.076296 | Acc 0.179748
# best testing accuarcy: 0.18556201550387597
# 0.18556201550387597

# %% [markdown]
# ##### K = 8

# %% [markdown]
# ##### Block duration = 6*TR

# %%
#Model params 
k_order = 6
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)

# %% [markdown]
# ##### Block duration = 8*TR

# %%
#Model params 
k_order = 8
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(8, 32, K=8)
#     (1): ChebConv(32, 32, K=8)
#     (2): ChebConv(32, 32, K=8)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 80624 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:739.784038 | Training Loss 0.066139 | Acc 0.055016
# Test Loss 0.059645 | Acc 0.104651
# Model updated: Best-Acc = 0.104651
#
# Epoch 1:
# Time Usage:741.762217 | Training Loss 0.058464 | Acc 0.144337
# Test Loss 0.053052 | Acc 0.282300
# Model updated: Best-Acc = 0.282300
#
# Epoch 2:
# Time Usage:742.826470 | Training Loss 0.050490 | Acc 0.250890
# Test Loss 0.047473 | Acc 0.425711
# Model updated: Best-Acc = 0.425711
#
# Epoch 3:
# Time Usage:740.973504 | Training Loss 0.042989 | Acc 0.352994
# Test Loss 0.038233 | Acc 0.567183
# Model updated: Best-Acc = 0.567183
#
# Epoch 4:
# Time Usage:738.268159 | Training Loss 0.038207 | Acc 0.429531
# Test Loss 0.034744 | Acc 0.621770
# Model updated: Best-Acc = 0.621770
#
# Epoch 5:
# Time Usage:738.414795 | Training Loss 0.034981 | Acc 0.483900
# Test Loss 0.032457 | Acc 0.625323
# Model updated: Best-Acc = 0.625323
#
# Epoch 6:
# Time Usage:747.144501 | Training Loss 0.032466 | Acc 0.527346
# Test Loss 0.030622 | Acc 0.661176
# Model updated: Best-Acc = 0.661176
#
# Epoch 7:
# Time Usage:741.999107 | Training Loss 0.030033 | Acc 0.568528
# Test Loss 0.027632 | Acc 0.708010
# Model updated: Best-Acc = 0.708010
#
# Epoch 8:
# Time Usage:740.642660 | Training Loss 0.028863 | Acc 0.589482
# Test Loss 0.024689 | Acc 0.730943
# Model updated: Best-Acc = 0.730943
#
# Epoch 9:
# Time Usage:745.669856 | Training Loss 0.027040 | Acc 0.620065
# Test Loss 0.026900 | Acc 0.699612
# best testing accuarcy: 0.7309431524547804
# 0.7309431524547804

# %% [markdown]
# ##### Block duration = 16*TR

# %%
#Model params 
k_order = 8
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(16, 32, K=8)
#     (1): ChebConv(32, 32, K=8)
#     (2): ChebConv(32, 32, K=8)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=16, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=16, bias=True)
#   )
# )
# 79776 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:536.545885 | Training Loss 0.087716 | Acc 0.075121
# Test Loss 0.082718 | Acc 0.129360
# Model updated: Best-Acc = 0.129360
#
# Epoch 1:
# Time Usage:539.073224 | Training Loss 0.082745 | Acc 0.117718
# Test Loss 0.081606 | Acc 0.117733
#
# Epoch 2:
# Time Usage:536.681516 | Training Loss 0.080891 | Acc 0.123665
# Test Loss 0.081380 | Acc 0.117248
#
# Epoch 3:
# Time Usage:533.004806 | Training Loss 0.081302 | Acc 0.120388
# Test Loss 0.080683 | Acc 0.129845
# Model updated: Best-Acc = 0.129845
#
# Epoch 4:
# Time Usage:534.958637 | Training Loss 0.080493 | Acc 0.127184
# Test Loss 0.080305 | Acc 0.130329
# Model updated: Best-Acc = 0.130329
#
# Epoch 5:
# Time Usage:536.448241 | Training Loss 0.081154 | Acc 0.117840
# Test Loss 0.080358 | Acc 0.122578
#
# Epoch 6:
# Time Usage:559.634648 | Training Loss 0.080416 | Acc 0.117354
# Test Loss 0.080543 | Acc 0.124516
#
# Epoch 7:
# Time Usage:563.431437 | Training Loss 0.080307 | Acc 0.125850
# Test Loss 0.080056 | Acc 0.127907
#
# Epoch 8:
# Time Usage:539.735002 | Training Loss 0.080534 | Acc 0.124757
# Test Loss 0.082311 | Acc 0.117733
#
# Epoch 9:
# Time Usage:540.722752 | Training Loss 0.080854 | Acc 0.121238
# Test Loss 0.080300 | Acc 0.121609
# best testing accuarcy: 0.1303294573643411
# 0.1303294573643411

# %% [markdown]
# ## Repeated Trials <a class="anchor" id="repeated_trials"></a>
