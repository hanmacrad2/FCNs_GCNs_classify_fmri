# %% [markdown]
# ## Overview: fmri movie data (camcan study) + application of gcns
# - Gcns used to classify blocks of fmri data in the movie across subjects

# %% [markdown]
# #### Glossary
# - TR: Repetition time - time it takes to scan all 32 slices.
# - fmri data: 193 Timepoints (193 x 2.47 = 476 secs = 7.9 mins) x 400 ROIs

# %% [markdown]
# #### Contents

# %% [markdown]
# * [1. Data](#data)
# * [2. Inspect data](#inspect_data)
# * [3. Fmri - filtered & normalised](#filter_norm)
#     * [3.1 Data loader](#data_loader)
#     * [4. FCNs](#fcn)
#     - Block durations of 6,8,
#     * [5. GCNs](#gcn)
#     - first order, 5th order neighbourhood
# * [4. Fmri - filtered only](#filter)
#     * [4.1 Data loader](#data_loader2)
#     * [4.2 FCNs](#fcn2)
#     - Block durations of 6,8,16
#     * [4.3 GCNs](#gcn2)
#     - first order, 5th order neighbourhood

# %% [markdown]
# #### Results summary

# %%
results = pd.DataFrame([[1, 2, 2], [4, 1, 5], [7,3, 8]],
     index=['row0', 'row1', 'row2'],
     columns=['col0','col1', 'col2'])
results
# Out:
#       col0  col1  col2
# row0     1     2     2
# row1     4     1     5
# row2     7     3     8

# %% [markdown]
# #### Imports

# %%
import os
import sys
import math
import time
import datetime

import numpy as np
import pandas as pd
import scipy.io

import nibabel as nib
from scipy import sparse
from scipy.stats import spearmanr
from sklearn import preprocessing, metrics,manifold
from sklearn.model_selection import cross_val_score, train_test_split,ShuffleSplit
import itertools


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

#from torch_scatter import scatter_add
##from torch_geometric.utils import add_self_loops
##from utils import add_self_loops

from util_funcs import *
from model import *

import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action='once')

#imports
#pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.7.0+cu102.html

#CPU
device = torch.device("cpu")
print(device)
# Out:
# cpu

# %%
#%load_ext autoreload
#%autoreload
#%reload_ext autoreload
#import sys
#reload(sys)
# Out:
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
check()
# Out:
# Hey there Check

# %% [markdown]
# ### 1. Data - fmri data <a class="anchor" id="data"></a>

# %%
#fmri
root_pth = '/camcan/schaefer_parc/'
fmri_movie, subj_list = get_fmri_data(root_pth, 'Movie')
print(np.array(fmri_movie).shape) #(193, 400)
print(len(subj_list)) #644 subjects
fmri_movie_copy = fmri_movie.copy()
# Out:
# (644, 193, 400)
# 644

# %%
#Adjacency matrix 
root_pth = '/camcan/schaefer_parc/'
adj_mat = get_rsfmri_adj_matrix(root_pth)
#plot_corr_matrix(adj_mat)
# Out:
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# ...
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:68: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   std[std < np.finfo(np.float).eps] = 1.  # avoid numerical problems

# %%
np.min(adj_mat)
# Out:
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# -0.029650910855963202

# %%
#Adjacency matrix
adj_mat = Adjacency_matrix(adj_mat, n_neighbours = 8).get_adj_sp_torch_tensor()
adj_mat
# Out:
# tensor(indices=tensor([[  1,   2,   3,  ..., 396, 397, 398],
#                        [  0,   0,   0,  ..., 399, 399, 399]]),
#        values=tensor([0.3348, 0.4519, 0.3895,  ..., 0.4030, 0.5090, 0.3403]),
#        size=(400, 400), nnz=4198, layout=torch.sparse_coo)

# %%
#Params
TR = 2.47
n_subjects = np.array(fmri_movie).shape[0]
print(f'N subjects = {n_subjects}')
n_regions = np.array(fmri_movie).shape[2]
# Out:
# N subjects = 644

# %%
#Specify block duration
block_duration = 8 #16 #6 8 -Factor of 192 
total_time = fmri_movie.shape[1]
n_blocks = total_time // block_duration
n_labels = n_blocks
print(f'Number of blocks = {n_blocks}')
total_time = block_duration*n_blocks #Rounded number 
print(f'Total time = {total_time}')
# Out:
# Number of blocks = 24
# Total time = 192

# %% [markdown]
# ### 2.  Inspect data <a class="anchor" id="inspect_data"></a>

# %%
#Original - Plot x1 subject -1st ROI
subj_num = 1; ROI_num = 1;
fmri_1 = np.array(fmri_movie)[subj_num,:,ROI_num]
print(fmri_1.shape)
idx = range(0, len(fmri_1))
plt.plot(idx, fmri_1)
# Out:
# (193,)

# %% [markdown]
# ##### Normalised data

# %%
#Normalise
scaler = preprocessing.StandardScaler()
fmri_norm_1 = np.expand_dims(fmri_1, axis = 0).T
print(fmri_norm_1.shape)
fmri_norm_1 = scaler.fit_transform(fmri_norm_1)
plt.plot(idx, fmri_norm_1)
#plt.plot(idx, fmri_data_roi1[0,:])
# Out:
# (193, 1)
# /home/hannahcraddock/anaconda3/envs/hannah_env/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ##### Filtered data

# %%
#### Detrend data
fmri_filtered = nilearn.signal.clean(np.array(fmri_movie_copy)[1,:,:], sessions=None, detrend=True, 
                                       standardize='psc', confounds=None, low_pass=0.1, 
                                       high_pass=0.01, t_r=0.392, ensure_finite=False)
print(np.array(fmri_filtered).shape)
# Out:
# (193, 400)

# %%
#Filter
fmri_filtered1 = nilearn.signal.clean(fmri_norm_1, sessions=None, detrend=True, 
                                       standardize='zscore', confounds=None, low_pass=0.1, 
                                       high_pass=0.01, t_r= TR, ensure_finite=False)
#Plot
plt.plot(idx, fmri_filtered1)

# %% [markdown]
# ## 3. Filtered + Normalised Data <a class="anchor" id="filter_norm"></a>

# %%
def filter_fmri(fmri, standardize):  
    'filter fmri signal'
    
    #fmri
    fmri_filtered = []
    for subj in np.arange(0, fmri_movie_copy.shape[0]):
        fmri_subj = fmri_movie_copy[subj]
        filtered = nilearn.signal.clean(fmri_subj, sessions= None, detrend=True, 
                               standardize= False, confounds=None, low_pass= 0.1, 
                               high_pass= 0.01, t_r = TR, ensure_finite=False)
        fmri_filtered.append(filtered)
    
    return fmri_filtered

# %%
#Apply
standardize =  'zscore' #'psc', False
fmri_filtered = filter_fmri(fmri_movie_copy, standardize)
print(np.array(fmri_filtered).shape)
# Out:
# /home/hannahcraddock/anaconda3/envs/env_python38/lib/python3.8/site-packages/nilearn/signal.py:204: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if not std < np.finfo(np.float).eps:
# (644, 193, 400)

# %% [markdown]
# ### 3.1  Dataloader (Train & Test sets) <a class="anchor" id="data_loader"></a>

# %%
#Split into train and test 
params = {'batch_size': 2, 
          'shuffle': True,
          'num_workers': 2}

test_size = 0.2
randomseed= 12345
rs = np.random.RandomState(randomseed)
#Training/Test indices
train_idx, test_idx = train_test_split(range(n_subjects), test_size = test_size, random_state=rs, shuffle=True)
print('Training on %d subjects, Testing on %d subjects' % (len(train_idx), len(test_idx)))
# Out:
# Training on 515 subjects, Testing on 129 subjects

# %%
#Train set
print(f'Block duration = {block_duration}')
fmri_data_train = [fmri_filtered[i] for i in train_idx] #Training subjects 
print(np.array(fmri_data_train).shape)
fmri_train = Fmri_dataset(fmri_data_train, TR, block_duration)
train_loader = DataLoader(fmri_train, collate_fn = fmri_samples_collate_fn, **params)

#Test set
fmri_data_test = [fmri_filtered[i] for i in test_idx]
print(np.array(fmri_data_test).shape)
fmri_test = Fmri_dataset(fmri_data_test, TR, block_duration)
test_loader = DataLoader(fmri_test, collate_fn=fmri_samples_collate_fn, **params)
# Out:
# Block duration = 8
# (515, 193, 400)
# (129, 193, 400)

# %% [markdown]
# ### 3.2 FCN <a class="anchor" id="fcn"></a>
#
# - Data = Filtered + Normalised

# %% [markdown]
# ##### Block duration = 8*TR

# %%
#CPU
print(f'Block duration = {block_duration}')

#Define model 
model = FCN(n_regions, n_labels) #time points == x, regions == rows 
model = model.to(device)
print(model)
print("{} paramters to be trained in the model\n".format(count_parameters(model)))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
#adj_mat = 'a'

model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# cpu
# FCN(
#   (linear): Linear(in_features=400, out_features=128, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 56248 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:2.089743 | Training Loss 0.047025 | Acc 0.332201
# Test Loss 0.026241 | Acc 0.721899
# Model updated: Best-Acc = 0.721899
#
# Epoch 1:
# Time Usage:1.940850 | Training Loss 0.029784 | Acc 0.581068
# Test Loss 0.018509 | Acc 0.802649
# Model updated: Best-Acc = 0.802649
#
# Epoch 2:
# Time Usage:2.073427 | Training Loss 0.024740 | Acc 0.653155
# Test Loss 0.014441 | Acc 0.837855
# Model updated: Best-Acc = 0.837855
#
# Epoch 3:
# Time Usage:1.983021 | Training Loss 0.020553 | Acc 0.708657
# Test Loss 0.016949 | Acc 0.796835
#
# Epoch 4:
# Time Usage:2.076088 | Training Loss 0.019066 | Acc 0.736408
# Test Loss 0.012225 | Acc 0.859496
# Model updated: Best-Acc = 0.859496
#
# Epoch 5:
# Time Usage:2.132248 | Training Loss 0.017133 | Acc 0.760518
# Test Loss 0.011416 | Acc 0.866279
# Model updated: Best-Acc = 0.866279
#
# Epoch 6:
# Time Usage:2.113567 | Training Loss 0.016556 | Acc 0.767880
# Test Loss 0.011798 | Acc 0.865633
#
# Epoch 7:
# Time Usage:2.102252 | Training Loss 0.016673 | Acc 0.770146
# Test Loss 0.012973 | Acc 0.861434
#
# Epoch 8:
# Time Usage:2.052160 | Training Loss 0.015143 | Acc 0.776294
# Test Loss 0.010321 | Acc 0.883075
# Model updated: Best-Acc = 0.883075
#
# Epoch 9:
# Time Usage:2.143685 | Training Loss 0.014217 | Acc 0.792880
# Test Loss 0.010013 | Acc 0.892442
# Model updated: Best-Acc = 0.892442
# best testing accuarcy: 0.8924418604651163
# 0.8924418604651163

# %% [markdown]
# ##### Block duration = 16*TR

# %%
print(f'Block duration = {block_duration}')

#CPU
device = torch.device("cpu")
print(device)

#Define model 
model = FCN(n_regions, n_labels) #time points == x, regions == rows 
model = model.to(device)
print(model)
print("{} paramters to be trained in the model\n".format(count_parameters(model)))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
loss_func = nn.CrossEntropyLoss()
num_epochs=10
#adj_mat = 'a'

model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# cpu
# FCN(
#   (linear): Linear(in_features=400, out_features=128, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=32, out_features=12, bias=True)
#   )
# )
# 55852 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:1.951157 | Training Loss 0.065465 | Acc 0.481715
# Test Loss 0.030564 | Acc 0.819767
# Model updated: Best-Acc = 0.819767
#
# Epoch 1:
# Time Usage:1.924635 | Training Loss 0.035742 | Acc 0.743689
# Test Loss 0.022310 | Acc 0.860465
# Model updated: Best-Acc = 0.860465
#
# Epoch 2:
# Time Usage:1.972935 | Training Loss 0.026227 | Acc 0.813592
# Test Loss 0.016785 | Acc 0.904393
# Model updated: Best-Acc = 0.904393
#
# Epoch 3:
# Time Usage:1.945542 | Training Loss 0.022982 | Acc 0.838188
# Test Loss 0.014480 | Acc 0.906977
# Model updated: Best-Acc = 0.906977
#
# Epoch 4:
# Time Usage:1.945197 | Training Loss 0.021418 | Acc 0.861003
# Test Loss 0.014719 | Acc 0.906977
#
# Epoch 5:
# Time Usage:1.959460 | Training Loss 0.018296 | Acc 0.871845
# Test Loss 0.015387 | Acc 0.895349
#
# Epoch 6:
# Time Usage:1.858853 | Training Loss 0.018493 | Acc 0.870388
# Test Loss 0.014376 | Acc 0.908269
# Model updated: Best-Acc = 0.908269
#
# Epoch 7:
# Time Usage:1.958957 | Training Loss 0.017309 | Acc 0.879450
# Test Loss 0.013351 | Acc 0.915375
# Model updated: Best-Acc = 0.915375
#
# Epoch 8:
# Time Usage:1.894550 | Training Loss 0.015429 | Acc 0.887379
# Test Loss 0.010936 | Acc 0.927649
# Model updated: Best-Acc = 0.927649
#
# Epoch 9:
# Time Usage:2.000929 | Training Loss 0.015783 | Acc 0.888673
# Test Loss 0.011296 | Acc 0.924419
# best testing accuarcy: 0.9276485788113695
# 0.9276485788113695

# %% [markdown]
# ##### Block duration = 6*TR

# %%
#Block duration
print(f'Block duration = {block_duration}')

#Define model 
model = FCN(n_regions, n_labels) #time points == x, regions == rows 
model = model.to(device)
print(model)
print("{} paramters to be trained in the model\n".format(count_parameters(model)))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
loss_func = nn.CrossEntropyLoss()
num_epochs=10
#adj_mat = 'a'

model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 6
# FCN(
#   (linear): Linear(in_features=400, out_features=128, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=32, out_features=32, bias=True)
#   )
# )
# 56512 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:1.299445 | Training Loss 0.077959 | Acc 0.408576
# Test Loss 0.036388 | Acc 0.741602
# Model updated: Best-Acc = 0.741602
#
# Epoch 1:
# Time Usage:1.236743 | Training Loss 0.038759 | Acc 0.691748
# Test Loss 0.025278 | Acc 0.837855
# Model updated: Best-Acc = 0.837855
#
# Epoch 2:
# Time Usage:1.300997 | Training Loss 0.030223 | Acc 0.771845
# Test Loss 0.019469 | Acc 0.888889
# Model updated: Best-Acc = 0.888889
#
# Epoch 3:
# Time Usage:1.274384 | Training Loss 0.026392 | Acc 0.801942
# Test Loss 0.015539 | Acc 0.897287
# Model updated: Best-Acc = 0.897287
#
# Epoch 4:
# Time Usage:1.318866 | Training Loss 0.022173 | Acc 0.841909
# Test Loss 0.014063 | Acc 0.910853
# Model updated: Best-Acc = 0.910853
#
# Epoch 5:
# Time Usage:1.226065 | Training Loss 0.019395 | Acc 0.862460
# Test Loss 0.012723 | Acc 0.920543
# Model updated: Best-Acc = 0.920543
#
# Epoch 6:
# Time Usage:1.286564 | Training Loss 0.018569 | Acc 0.869579
# Test Loss 0.013395 | Acc 0.911499
#
# Epoch 7:
# Time Usage:1.244837 | Training Loss 0.016335 | Acc 0.881553
# Test Loss 0.012561 | Acc 0.909561
#
# Epoch 8:
# Time Usage:1.248791 | Training Loss 0.014725 | Acc 0.892718
# Test Loss 0.013401 | Acc 0.898579
#
# Epoch 9:
# Time Usage:1.269672 | Training Loss 0.019672 | Acc 0.879288
# Test Loss 0.010982 | Acc 0.930879
# Model updated: Best-Acc = 0.930879
# best testing accuarcy: 0.9308785529715762
# 0.9308785529715762

# %% [markdown]
# ### 2. GCN <a class="anchor" id="gcn"></a>

# %% [markdown]
# ##### Block duration = 6*TR
# - __First Order__

# %%
from model import ChebNet

print(f'Block duration = {block_duration}')
#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 6
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (6 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=32, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=32, bias=True)
#   )
# )
# 65280 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:225.551904 | Training Loss 0.053592 | Acc 0.050303
# Test Loss 0.050195 | Acc 0.108043
# Model updated: Best-Acc = 0.108043
#
# Epoch 1:
# Time Usage:225.529149 | Training Loss 0.047543 | Acc 0.115413
# Test Loss 0.043703 | Acc 0.250242
# Model updated: Best-Acc = 0.250242
#
# Epoch 2:
# Time Usage:226.543114 | Training Loss 0.042613 | Acc 0.192718
# Test Loss 0.038379 | Acc 0.335029
# Model updated: Best-Acc = 0.335029
#
# Epoch 3:
# Time Usage:226.495095 | Training Loss 0.039546 | Acc 0.241748
# Test Loss 0.037818 | Acc 0.329215
#
# Epoch 4:
# Time Usage:223.551052 | Training Loss 0.038133 | Acc 0.264563
# Test Loss 0.035027 | Acc 0.390988
# Model updated: Best-Acc = 0.390988
#
# Epoch 5:
# Time Usage:227.120148 | Training Loss 0.036400 | Acc 0.294175
# Test Loss 0.035281 | Acc 0.403343
# Model updated: Best-Acc = 0.403343
#
# Epoch 6:
# Time Usage:227.194162 | Training Loss 0.035549 | Acc 0.308617
# Test Loss 0.032859 | Acc 0.427568
# Model updated: Best-Acc = 0.427568
#
# Epoch 7:
# Time Usage:226.820953 | Training Loss 0.035143 | Acc 0.319114
# Test Loss 0.032990 | Acc 0.427083
#
# Epoch 8:
# Time Usage:226.905842 | Training Loss 0.034125 | Acc 0.335376
# Test Loss 0.030134 | Acc 0.462936
# Model updated: Best-Acc = 0.462936
#
# Epoch 9:
# Time Usage:229.330604 | Training Loss 0.033805 | Acc 0.339320
# Test Loss 0.030931 | Acc 0.445010
# best testing accuarcy: 0.4629360465116279
# 0.4629360465116279

# %% [markdown]
# #### GCN - expanding to k-th order neighborhood (connecting by k steps)

# %% [markdown]
# #### Block duration = 6

# %% [markdown]
# - Fifth Order K = 5

# %%
#Model params 
k_order = 5
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 6
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(6, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=32, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=32, bias=True)
#   )
# )
# 76480 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:752.463936 | Training Loss 0.053702 | Acc 0.054915
# Test Loss 0.051327 | Acc 0.132510
# Model updated: Best-Acc = 0.132510
#
# Epoch 1:
# Time Usage:751.202523 | Training Loss 0.046873 | Acc 0.161954
# Test Loss 0.041751 | Acc 0.328004
# Model updated: Best-Acc = 0.328004
#
# Epoch 2:
# Time Usage:752.511991 | Training Loss 0.039964 | Acc 0.260498
# Test Loss 0.037096 | Acc 0.451550
# Model updated: Best-Acc = 0.451550
#
# Epoch 3:
# Time Usage:752.404421 | Training Loss 0.035107 | Acc 0.347148
# Test Loss 0.029601 | Acc 0.522287
# Model updated: Best-Acc = 0.522287
#
# Epoch 4:
# Time Usage:755.899206 | Training Loss 0.031646 | Acc 0.411772
# Test Loss 0.026659 | Acc 0.583333
# Model updated: Best-Acc = 0.583333
#
# Epoch 5:
# Time Usage:757.538645 | Training Loss 0.028818 | Acc 0.460680
# Test Loss 0.027673 | Acc 0.593508
# Model updated: Best-Acc = 0.593508
#
# Epoch 6:
# Time Usage:754.191556 | Training Loss 0.027056 | Acc 0.496602
# Test Loss 0.024664 | Acc 0.632267
# Model updated: Best-Acc = 0.632267
#
# Epoch 7:
# Time Usage:755.816314 | Training Loss 0.025627 | Acc 0.522330
# Test Loss 0.024253 | Acc 0.661095
# Model updated: Best-Acc = 0.661095
#
# Epoch 8:
# Time Usage:755.186918 | Training Loss 0.024064 | Acc 0.552731
# Test Loss 0.020461 | Acc 0.689196
# Model updated: Best-Acc = 0.689196
#
# Epoch 9:
# Time Usage:756.009348 | Training Loss 0.022935 | Acc 0.576032
# Test Loss 0.020873 | Acc 0.694041
# Model updated: Best-Acc = 0.694041
# best testing accuarcy: 0.6940406976744186
# 0.6940406976744186

# %% [markdown]
# __K = 8__

# %%
#Model params 
k_order = 8
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K= k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 6
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(6, 32, K=8)
#     (1): ChebConv(32, 32, K=8)
#     (2): ChebConv(32, 32, K=8)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=32, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=32, bias=True)
#   )
# )
# 83200 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:1201.548095 | Training Loss 0.054054 | Acc 0.044357
# Test Loss 0.050579 | Acc 0.114583
# Model updated: Best-Acc = 0.114583
#
# Epoch 1:
# Time Usage:1191.653200 | Training Loss 0.047630 | Acc 0.129248
# Test Loss 0.042566 | Acc 0.240552
# Model updated: Best-Acc = 0.240552
#
# Epoch 2:
# Time Usage:1184.992729 | Training Loss 0.041799 | Acc 0.222269
# Test Loss 0.037537 | Acc 0.382025
# Model updated: Best-Acc = 0.382025
#
# Epoch 3:
# Time Usage:1204.328098 | Training Loss 0.036721 | Acc 0.304430
# Test Loss 0.033019 | Acc 0.499031
# Model updated: Best-Acc = 0.499031
#
# Epoch 4:
# Time Usage:1196.170222 | Training Loss 0.033111 | Acc 0.370449
# Test Loss 0.029574 | Acc 0.561531
# Model updated: Best-Acc = 0.561531
#
# Epoch 5:
# Time Usage:1195.551656 | Training Loss 0.030261 | Acc 0.429066
# Test Loss 0.026484 | Acc 0.608769
# Model updated: Best-Acc = 0.608769
#
# Epoch 6:
# Time Usage:1200.008619 | Training Loss 0.027827 | Acc 0.468325
# Test Loss 0.024800 | Acc 0.652859
# Model updated: Best-Acc = 0.652859
#
# Epoch 7:
# Time Usage:1194.007957 | Training Loss 0.026366 | Acc 0.501032
# Test Loss 0.021623 | Acc 0.695736
# Model updated: Best-Acc = 0.695736
#
# Epoch 8:
# Time Usage:1188.256520 | Training Loss 0.024831 | Acc 0.539867
# Test Loss 0.023201 | Acc 0.673450
#
# Epoch 9:
# Time Usage:1201.237818 | Training Loss 0.023358 | Acc 0.565109
# Test Loss 0.022413 | Acc 0.678295
# best testing accuarcy: 0.6957364341085271
# 0.6957364341085271

# %% [markdown]
# ##### Block duration = 16*TR
# - First order

# %%
from model import ChebNet

print(f'Block duration = {block_duration}')
#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (16 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=12, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=12, bias=True)
#   )
# )
# 57720 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:73.826509 | Training Loss 0.104322 | Acc 0.084142
# Test Loss 0.104347 | Acc 0.083333
# Model updated: Best-Acc = 0.083333
#
# Epoch 1:
# Time Usage:74.350230 | Training Loss 0.103725 | Acc 0.086084
# Test Loss 0.103601 | Acc 0.083333
#
# Epoch 2:
# Time Usage:75.088261 | Training Loss 0.098248 | Acc 0.146278
# Test Loss 0.093342 | Acc 0.215762
# Model updated: Best-Acc = 0.215762
#
# Epoch 3:
# Time Usage:75.865599 | Training Loss 0.089525 | Acc 0.219903
# Test Loss 0.078037 | Acc 0.350775
# Model updated: Best-Acc = 0.350775
#
# Epoch 4:
# Time Usage:74.709764 | Training Loss 0.079409 | Acc 0.301133
# Test Loss 0.069778 | Acc 0.433463
# Model updated: Best-Acc = 0.433463
#
# Epoch 5:
# Time Usage:74.578950 | Training Loss 0.071038 | Acc 0.381877
# Test Loss 0.059841 | Acc 0.498708
# Model updated: Best-Acc = 0.498708
#
# Epoch 6:
# Time Usage:75.550223 | Training Loss 0.064929 | Acc 0.419903
# Test Loss 0.056413 | Acc 0.522610
# Model updated: Best-Acc = 0.522610
#
# Epoch 7:
# Time Usage:75.749055 | Training Loss 0.061683 | Acc 0.465858
# Test Loss 0.054875 | Acc 0.556202
# Model updated: Best-Acc = 0.556202
#
# Epoch 8:
# Time Usage:74.939023 | Training Loss 0.059157 | Acc 0.487864
# Test Loss 0.063002 | Acc 0.477390
#
# Epoch 9:
# Time Usage:74.939548 | Training Loss 0.060022 | Acc 0.475728
# Test Loss 0.050407 | Acc 0.614987
# Model updated: Best-Acc = 0.614987
# best testing accuarcy: 0.6149870801033591
# 0.6149870801033591

# %% [markdown]
# #### GCN - expanding to k-th order neighborhood (connecting by k steps)

# %% [markdown]
# __K = 5__

# %%
#Model params 
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=5, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(16, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=12, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=12, bias=True)
#   )
# )
# 70520 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:262.898543 | Training Loss 0.099694 | Acc 0.165372
# Test Loss 0.091366 | Acc 0.313307
# Model updated: Best-Acc = 0.313307
#
# Epoch 1:
# Time Usage:260.722314 | Training Loss 0.085912 | Acc 0.288188
# Test Loss 0.078377 | Acc 0.463824
# Model updated: Best-Acc = 0.463824
#
# Epoch 2:
# Time Usage:261.217229 | Training Loss 0.073317 | Acc 0.408900
# Test Loss 0.067268 | Acc 0.589147
# Model updated: Best-Acc = 0.589147
#
# Epoch 3:
# Time Usage:260.277550 | Training Loss 0.061539 | Acc 0.526861
# Test Loss 0.055289 | Acc 0.695736
# Model updated: Best-Acc = 0.695736
#
# Epoch 4:
# Time Usage:237.852780 | Training Loss 0.050692 | Acc 0.607767
# Test Loss 0.062208 | Acc 0.585271
#
# Epoch 5:
# Time Usage:198.142981 | Training Loss 0.045716 | Acc 0.649838
# Test Loss 0.040001 | Acc 0.744186
# Model updated: Best-Acc = 0.744186
#
# Epoch 6:
# Time Usage:197.719430 | Training Loss 0.041003 | Acc 0.700809
# Test Loss 0.035482 | Acc 0.781008
# Model updated: Best-Acc = 0.781008
#
# Epoch 7:
# Time Usage:196.323396 | Training Loss 0.036369 | Acc 0.730259
# Test Loss 0.032205 | Acc 0.798450
# Model updated: Best-Acc = 0.798450
#
# Epoch 8:
# Time Usage:195.383844 | Training Loss 0.034261 | Acc 0.747249
# Test Loss 0.026589 | Acc 0.844315
# Model updated: Best-Acc = 0.844315
#
# Epoch 9:
# Time Usage:195.660527 | Training Loss 0.031913 | Acc 0.762136
# Test Loss 0.027761 | Acc 0.837855
# best testing accuarcy: 0.8443152454780362
# 0.8443152454780362

# %% [markdown]
# __K = 8__

# %%
#Model params 
k_order = 8
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K= k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(16, 32, K=8)
#     (1): ChebConv(32, 32, K=8)
#     (2): ChebConv(32, 32, K=8)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=12, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=12, bias=True)
#   )
# )
# 78200 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:309.104297 | Training Loss 0.101765 | Acc 0.140291
# Test Loss 0.086065 | Acc 0.299742
# Model updated: Best-Acc = 0.299742
#
# Epoch 1:
# Time Usage:305.677657 | Training Loss 0.081510 | Acc 0.313107
# Test Loss 0.072405 | Acc 0.447674
# Model updated: Best-Acc = 0.447674
#
# Epoch 2:
# Time Usage:307.734573 | Training Loss 0.071732 | Acc 0.401618
# Test Loss 0.067202 | Acc 0.501938
# Model updated: Best-Acc = 0.501938
#
# Epoch 3:
# Time Usage:309.135857 | Training Loss 0.063760 | Acc 0.479288
# Test Loss 0.059461 | Acc 0.607235
# Model updated: Best-Acc = 0.607235
#
# Epoch 4:
# Time Usage:310.854897 | Training Loss 0.055406 | Acc 0.562298
# Test Loss 0.048709 | Acc 0.683463
# Model updated: Best-Acc = 0.683463
#
# Epoch 5:
# Time Usage:310.298045 | Training Loss 0.049258 | Acc 0.621197
# Test Loss 0.044579 | Acc 0.729328
# Model updated: Best-Acc = 0.729328
#
# Epoch 6:
# Time Usage:310.497993 | Training Loss 0.042052 | Acc 0.679935
# Test Loss 0.043154 | Acc 0.762274
# Model updated: Best-Acc = 0.762274
#
# Epoch 7:
# Time Usage:313.653706 | Training Loss 0.039909 | Acc 0.703074
# Test Loss 0.036135 | Acc 0.795220
# Model updated: Best-Acc = 0.795220
#
# Epoch 8:
# Time Usage:313.705451 | Training Loss 0.036863 | Acc 0.734628
# Test Loss 0.031445 | Acc 0.795220
#
# Epoch 9:
# Time Usage:313.005179 | Training Loss 0.034211 | Acc 0.751456
# Test Loss 0.027517 | Acc 0.828811
# Model updated: Best-Acc = 0.828811
# best testing accuarcy: 0.8288113695090439
# 0.8288113695090439

# %% [markdown]
# ##### Block duration = 8*TR
# - First order

# %%
from model import ChebNet

print(f'Block duration = {block_duration}')
#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (8 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 62192 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:136.866987 | Training Loss 0.064037 | Acc 0.084790
# Test Loss 0.057415 | Acc 0.196705
# Model updated: Best-Acc = 0.196705
#
# Epoch 1:
# Time Usage:136.333657 | Training Loss 0.053554 | Acc 0.214887
# Test Loss 0.048254 | Acc 0.322674
# Model updated: Best-Acc = 0.322674
#
# Epoch 2:
# Time Usage:136.277246 | Training Loss 0.047754 | Acc 0.287702
# Test Loss 0.043124 | Acc 0.381783
# Model updated: Best-Acc = 0.381783
#
# Epoch 3:
# Time Usage:136.923594 | Training Loss 0.045947 | Acc 0.303236
# Test Loss 0.041699 | Acc 0.418605
# Model updated: Best-Acc = 0.418605
#
# Epoch 4:
# Time Usage:136.191245 | Training Loss 0.043657 | Acc 0.331230
# Test Loss 0.038679 | Acc 0.445413
# Model updated: Best-Acc = 0.445413
#
# Epoch 5:
# Time Usage:136.219376 | Training Loss 0.042057 | Acc 0.348786
# Test Loss 0.038809 | Acc 0.456072
# Model updated: Best-Acc = 0.456072
#
# Epoch 6:
# Time Usage:136.997657 | Training Loss 0.041643 | Acc 0.360680
# Test Loss 0.037164 | Acc 0.488372
# Model updated: Best-Acc = 0.488372
#
# Epoch 7:
# Time Usage:137.639931 | Training Loss 0.040238 | Acc 0.382201
# Test Loss 0.036269 | Acc 0.487726
#
# Epoch 8:
# Time Usage:137.690120 | Training Loss 0.038907 | Acc 0.398058
# Test Loss 0.035634 | Acc 0.509690
# Model updated: Best-Acc = 0.509690
#
# Epoch 9:
# Time Usage:137.668896 | Training Loss 0.039634 | Acc 0.387783
# Test Loss 0.035046 | Acc 0.499031
# best testing accuarcy: 0.5096899224806202
# 0.5096899224806202

# %% [markdown]
# #### GCN - expanding to k-th order neighborhood (connecting by k steps)

# %% [markdown]
# __K = 5__

# %%
#Model params 
k_order = 5
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(8, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 73712 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:461.768672 | Training Loss 0.063813 | Acc 0.096359
# Test Loss 0.056611 | Acc 0.254199
# Model updated: Best-Acc = 0.254199
#
# Epoch 1:
# Time Usage:462.501058 | Training Loss 0.053143 | Acc 0.233900
# Test Loss 0.044483 | Acc 0.389858
# Model updated: Best-Acc = 0.389858
#
# Epoch 2:
# Time Usage:463.215743 | Training Loss 0.045467 | Acc 0.327184
# Test Loss 0.040119 | Acc 0.468992
# Model updated: Best-Acc = 0.468992
#
# Epoch 3:
# Time Usage:458.726424 | Training Loss 0.038766 | Acc 0.416019
# Test Loss 0.032912 | Acc 0.602713
# Model updated: Best-Acc = 0.602713
#
# Epoch 4:
# Time Usage:462.504014 | Training Loss 0.034784 | Acc 0.475000
# Test Loss 0.028947 | Acc 0.660853
# Model updated: Best-Acc = 0.660853
#
# Epoch 5:
# Time Usage:462.674812 | Training Loss 0.031720 | Acc 0.533010
# Test Loss 0.026697 | Acc 0.691537
# Model updated: Best-Acc = 0.691537
#
# Epoch 6:
# Time Usage:463.343089 | Training Loss 0.029103 | Acc 0.572249
# Test Loss 0.022716 | Acc 0.753230
# Model updated: Best-Acc = 0.753230
#
# Epoch 7:
# Time Usage:463.317412 | Training Loss 0.026412 | Acc 0.621117
# Test Loss 0.022410 | Acc 0.765504
# Model updated: Best-Acc = 0.765504
#
# Epoch 8:
# Time Usage:463.881071 | Training Loss 0.024833 | Acc 0.647654
# Test Loss 0.020935 | Acc 0.776163
# Model updated: Best-Acc = 0.776163
#
# Epoch 9:
# Time Usage:468.758976 | Training Loss 0.022512 | Acc 0.683172
# Test Loss 0.017491 | Acc 0.825258
# Model updated: Best-Acc = 0.825258
# best testing accuarcy: 0.8252583979328165
# 0.8252583979328165

# %% [markdown]
# __K = 8__

# %%
#Model params 
k_order = 8
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K= k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(8, 32, K=8)
#     (1): ChebConv(32, 32, K=8)
#     (2): ChebConv(32, 32, K=8)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 80624 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:741.675057 | Training Loss 0.066621 | Acc 0.049272
# Test Loss 0.065641 | Acc 0.086886
# Model updated: Best-Acc = 0.086886
#
# Epoch 1:
# Time Usage:747.862950 | Training Loss 0.061434 | Acc 0.142071
# Test Loss 0.056878 | Acc 0.290052
# Model updated: Best-Acc = 0.290052
#
# Epoch 2:
# Time Usage:740.443576 | Training Loss 0.050903 | Acc 0.252427
# Test Loss 0.047135 | Acc 0.439276
# Model updated: Best-Acc = 0.439276
#
# Epoch 3:
# Time Usage:736.207062 | Training Loss 0.043404 | Acc 0.351375
# Test Loss 0.040763 | Acc 0.509367
# Model updated: Best-Acc = 0.509367
#
# Epoch 4:
# Time Usage:740.879949 | Training Loss 0.038792 | Acc 0.418770
# Test Loss 0.040318 | Acc 0.525840
# Model updated: Best-Acc = 0.525840
#
# Epoch 5:
# Time Usage:739.785724 | Training Loss 0.035091 | Acc 0.481230
# Test Loss 0.032940 | Acc 0.650194
# Model updated: Best-Acc = 0.650194
#
# Epoch 6:
# Time Usage:742.189692 | Training Loss 0.032587 | Acc 0.520712
# Test Loss 0.027018 | Acc 0.688307
# Model updated: Best-Acc = 0.688307
#
# Epoch 7:
# Time Usage:746.991251 | Training Loss 0.030446 | Acc 0.561327
# Test Loss 0.029565 | Acc 0.686693
#
# Epoch 8:
# Time Usage:738.504085 | Training Loss 0.028577 | Acc 0.591748
# Test Loss 0.024133 | Acc 0.760013
# Model updated: Best-Acc = 0.760013
#
# Epoch 9:
# Time Usage:740.818838 | Training Loss 0.026504 | Acc 0.628803
# Test Loss 0.023167 | Acc 0.770349
# Model updated: Best-Acc = 0.770349
# best testing accuarcy: 0.7703488372093024
# 0.7703488372093024

# %% [markdown]
# ## 4. Filtered + non-standardised data <a class="anchor" id="filter"></a>

# %%
def filter_fmri(fmri, standardize):  
    'filter fmri signal'
    
    #fmri
    fmri_filtered = []
    for subj in np.arange(0, fmri_movie_copy.shape[0]):
        fmri_subj = fmri_movie_copy[subj]
        filtered = nilearn.signal.clean(fmri_subj, sessions= None, detrend=True, 
                               standardize= False, confounds=None, low_pass= 0.1, 
                               high_pass= 0.01, t_r = TR, ensure_finite=False)
        fmri_filtered.append(filtered)
    
    return fmri_filtered

# %%
#Apply
standardize =  False #'psc', 'zscore'
fmri_filtered2 = filter_fmri(fmri_movie_copy, standardize)
print(np.array(fmri_filtered2).shape)
# Out:
# (644, 193, 400)

# %% [markdown]
# ### 4.1  Dataloader (Train & Test sets) <a class="anchor" id="data_loader2"></a>

# %%
#Split into train and test 
params = {'batch_size': 2, 
          'shuffle': True,
          'num_workers': 2}

test_size = 0.2
randomseed= 12345
rs = np.random.RandomState(randomseed)
#Training/Test indices
train_idx, test_idx = train_test_split(range(n_subjects), test_size = test_size, random_state=rs, shuffle=True)
print('Training on %d subjects, Testing on %d subjects' % (len(train_idx), len(test_idx)))
# Out:
# Training on 515 subjects, Testing on 129 subjects

# %%
#Train set
print(f'Block duration = {block_duration}')
fmri_data_train = [fmri_filtered2[i] for i in train_idx] #Training subjects 
print(np.array(fmri_data_train).shape)
fmri_train = Fmri_dataset(fmri_data_train, TR, block_duration)
train_loader = DataLoader(fmri_train, collate_fn = fmri_samples_collate_fn, **params)

#Test set
fmri_data_test = [fmri_filtered2[i] for i in test_idx]
print(np.array(fmri_data_test).shape)
fmri_test = Fmri_dataset(fmri_data_test, TR, block_duration)
test_loader = DataLoader(fmri_test, collate_fn=fmri_samples_collate_fn, **params)
# Out:
# Block duration = 8
# (515, 193, 400)
# (129, 193, 400)

# %% [markdown]
# ## 4.2 FCN <a class="anchor" id="fcn2"></a>

# %% [markdown]
# ##### Block duration = 6*TR

# %%
#Block duration
print(f'Block duration = {block_duration}')

#Define model 
model = FCN(n_regions, n_labels) #time points == x, regions == rows 
model = model.to(device)
print(model)
print("{} paramters to be trained in the model\n".format(count_parameters(model)))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
loss_func = nn.CrossEntropyLoss()
num_epochs=10
#adj_mat = 'a'

model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 6
# FCN(
#   (linear): Linear(in_features=400, out_features=128, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=32, out_features=32, bias=True)
#   )
# )
# 56512 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:1.497382 | Training Loss 0.039517 | Acc 0.285376
# Test Loss 0.026964 | Acc 0.600291
# Model updated: Best-Acc = 0.600291
#
# Epoch 1:
# Time Usage:1.465996 | Training Loss 0.026390 | Acc 0.508434
# Test Loss 0.017432 | Acc 0.769864
# Model updated: Best-Acc = 0.769864
#
# Epoch 2:
# Time Usage:1.469887 | Training Loss 0.021895 | Acc 0.592476
# Test Loss 0.014167 | Acc 0.817345
# Model updated: Best-Acc = 0.817345
#
# Epoch 3:
# Time Usage:1.455536 | Training Loss 0.019434 | Acc 0.638046
# Test Loss 0.013387 | Acc 0.826308
# Model updated: Best-Acc = 0.826308
#
# Epoch 4:
# Time Usage:1.467361 | Training Loss 0.017893 | Acc 0.663896
# Test Loss 0.010871 | Acc 0.859254
# Model updated: Best-Acc = 0.859254
#
# Epoch 5:
# Time Usage:1.436251 | Training Loss 0.017221 | Acc 0.673362
# Test Loss 0.010677 | Acc 0.860465
# Model updated: Best-Acc = 0.860465
#
# Epoch 6:
# Time Usage:1.461408 | Training Loss 0.016062 | Acc 0.700243
# Test Loss 0.010366 | Acc 0.861192
# Model updated: Best-Acc = 0.861192
#
# Epoch 7:
# Time Usage:1.463644 | Training Loss 0.015719 | Acc 0.703580
# Test Loss 0.010941 | Acc 0.851744
#
# Epoch 8:
# Time Usage:1.422226 | Training Loss 0.015274 | Acc 0.711590
# Test Loss 0.009775 | Acc 0.872820
# Model updated: Best-Acc = 0.872820
#
# Epoch 9:
# Time Usage:1.457690 | Training Loss 0.014008 | Acc 0.729126
# Test Loss 0.010170 | Acc 0.867733
# best testing accuarcy: 0.8728197674418605
# 0.8728197674418605

# %% [markdown]
# ##### Block duration = 16*TR

# %%
#Block duration
print(f'Block duration = {block_duration}')

#Define model 
model = FCN(n_regions, n_labels) #time points == x, regions == rows 
model = model.to(device)
print(model)
print("{} paramters to be trained in the model\n".format(count_parameters(model)))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
loss_func = nn.CrossEntropyLoss()
num_epochs=10
#adj_mat = 'a'

model_fit_evaluate(model, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# FCN(
#   (linear): Linear(in_features=400, out_features=128, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=32, out_features=12, bias=True)
#   )
# )
# 55852 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:1.231020 | Training Loss 0.065738 | Acc 0.488026
# Test Loss 0.033520 | Acc 0.791990
# Model updated: Best-Acc = 0.791990
#
# Epoch 1:
# Time Usage:1.226541 | Training Loss 0.035248 | Acc 0.733657
# Test Loss 0.020626 | Acc 0.874031
# Model updated: Best-Acc = 0.874031
#
# Epoch 2:
# Time Usage:1.284626 | Training Loss 0.025914 | Acc 0.818932
# Test Loss 0.017252 | Acc 0.899225
# Model updated: Best-Acc = 0.899225
#
# Epoch 3:
# Time Usage:1.270998 | Training Loss 0.024466 | Acc 0.829612
# Test Loss 0.020449 | Acc 0.874031
#
# Epoch 4:
# Time Usage:1.298714 | Training Loss 0.019491 | Acc 0.860680
# Test Loss 0.016229 | Acc 0.886305
#
# Epoch 5:
# Time Usage:1.225610 | Training Loss 0.017585 | Acc 0.872168
# Test Loss 0.012772 | Acc 0.916667
# Model updated: Best-Acc = 0.916667
#
# Epoch 6:
# Time Usage:1.296464 | Training Loss 0.018776 | Acc 0.867476
# Test Loss 0.013098 | Acc 0.917313
# Model updated: Best-Acc = 0.917313
#
# Epoch 7:
# Time Usage:1.279301 | Training Loss 0.017204 | Acc 0.875890
# Test Loss 0.010649 | Acc 0.930233
# Model updated: Best-Acc = 0.930233
#
# Epoch 8:
# Time Usage:1.239587 | Training Loss 0.016003 | Acc 0.893042
# Test Loss 0.010262 | Acc 0.927649
#
# Epoch 9:
# Time Usage:1.201211 | Training Loss 0.013066 | Acc 0.900647
# Test Loss 0.011378 | Acc 0.920543
# best testing accuarcy: 0.9302325581395349
# 0.9302325581395349

# %% [markdown]
# ### 4.3. GCN <a class="anchor" id="gcn2"></a>
# - First order

# %% [markdown]
# ##### Block duration = 6*TR

# %%
from model import ChebNet
print(f'Block duration = {block_duration}')

#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 6
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (6 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=32, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=32, bias=True)
#   )
# )
# 65280 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:225.142363 | Training Loss 0.051693 | Acc 0.072694
# Test Loss 0.047066 | Acc 0.190407
# Model updated: Best-Acc = 0.190407
#
# Epoch 1:
# Time Usage:227.704138 | Training Loss 0.044640 | Acc 0.168568
# Test Loss 0.039225 | Acc 0.317103
# Model updated: Best-Acc = 0.317103
#
# Epoch 2:
# Time Usage:226.753081 | Training Loss 0.040181 | Acc 0.235133
# Test Loss 0.035266 | Acc 0.377180
# Model updated: Best-Acc = 0.377180
#
# Epoch 3:
# Time Usage:225.380547 | Training Loss 0.037784 | Acc 0.269478
# Test Loss 0.036555 | Acc 0.371609
#
# Epoch 4:
# Time Usage:226.400907 | Training Loss 0.036636 | Acc 0.291080
# Test Loss 0.035902 | Acc 0.378876
# Model updated: Best-Acc = 0.378876
#
# Epoch 5:
# Time Usage:231.264858 | Training Loss 0.036231 | Acc 0.295388
# Test Loss 0.033059 | Acc 0.443798
# Model updated: Best-Acc = 0.443798
#
# Epoch 6:
# Time Usage:226.389706 | Training Loss 0.034479 | Acc 0.330036
# Test Loss 0.030670 | Acc 0.470446
# Model updated: Best-Acc = 0.470446
#
# Epoch 7:
# Time Usage:226.881569 | Training Loss 0.033984 | Acc 0.339502
# Test Loss 0.032201 | Acc 0.460271
#
# Epoch 8:
# Time Usage:227.814320 | Training Loss 0.033573 | Acc 0.339078
# Test Loss 0.030354 | Acc 0.466570
#
# Epoch 9:
# Time Usage:230.684716 | Training Loss 0.033080 | Acc 0.356371
# Test Loss 0.030815 | Acc 0.460756
# best testing accuarcy: 0.47044573643410853
# 0.47044573643410853

# %% [markdown]
# ##### Block duration = 8*TR

# %%
from model import ChebNet
print(f'Block duration = {block_duration}')

#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (8 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 62192 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:136.669055 | Training Loss 0.064165 | Acc 0.080178
# Test Loss 0.057848 | Acc 0.188953
# Model updated: Best-Acc = 0.188953
#
# Epoch 1:
# Time Usage:136.768747 | Training Loss 0.053608 | Acc 0.203883
# Test Loss 0.047031 | Acc 0.354005
# Model updated: Best-Acc = 0.354005
#
# Epoch 2:
# Time Usage:136.665167 | Training Loss 0.048493 | Acc 0.274110
# Test Loss 0.043271 | Acc 0.409561
# Model updated: Best-Acc = 0.409561
#
# Epoch 3:
# Time Usage:137.119146 | Training Loss 0.044841 | Acc 0.314725
# Test Loss 0.040702 | Acc 0.442506
# Model updated: Best-Acc = 0.442506
#
# Epoch 4:
# Time Usage:136.771467 | Training Loss 0.042836 | Acc 0.347411
# Test Loss 0.037841 | Acc 0.474806
# Model updated: Best-Acc = 0.474806
#
# Epoch 5:
# Time Usage:136.918263 | Training Loss 0.041895 | Acc 0.358819
# Test Loss 0.037519 | Acc 0.486434
# Model updated: Best-Acc = 0.486434
#
# Epoch 6:
# Time Usage:136.508248 | Training Loss 0.040253 | Acc 0.383010
# Test Loss 0.037086 | Acc 0.492894
# Model updated: Best-Acc = 0.492894
#
# Epoch 7:
# Time Usage:136.707421 | Training Loss 0.039900 | Acc 0.385437
# Test Loss 0.036830 | Acc 0.460594
#
# Epoch 8:
# Time Usage:137.771631 | Training Loss 0.039562 | Acc 0.383576
# Test Loss 0.037112 | Acc 0.461886
#
# Epoch 9:
# Time Usage:138.796329 | Training Loss 0.039299 | Acc 0.392314
# Test Loss 0.034081 | Acc 0.525517
# Model updated: Best-Acc = 0.525517
# best testing accuarcy: 0.525516795865633
# 0.525516795865633

# %% [markdown]
# ##### Block duration = 16*TR

# %%
from model import ChebNet
print(f'Block duration = {block_duration}')

#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 
model_test = ChebNet(block_duration, filters, n_labels, gcn_layer = num_layers,dropout=0.25,gcn_flag=True)
#model_test = ChebNet(block_dura, filters, Nlabels, K=5,gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test,adj_mat,device,train_loader,test_loader,optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# Using GCN Layers instead
# ChebNet(
#   (graph_features): ModuleList(
#     (0): GraphConv (16 -> 32)
#     (1): GraphConv (32 -> 32)
#     (2): GraphConv (32 -> 32)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=12, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=12, bias=True)
#   )
# )
# 57720 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:61.642321 | Training Loss 0.104322 | Acc 0.086084
# Test Loss 0.104350 | Acc 0.083333
# Model updated: Best-Acc = 0.083333
#
# Epoch 1:
# Time Usage:60.173254 | Training Loss 0.100472 | Acc 0.124595
# Test Loss 0.095063 | Acc 0.183463
# Model updated: Best-Acc = 0.183463
#
# Epoch 2:
# Time Usage:59.806158 | Training Loss 0.094006 | Acc 0.192395
# Test Loss 0.088441 | Acc 0.300388
# Model updated: Best-Acc = 0.300388
#
# Epoch 3:
# Time Usage:59.500402 | Training Loss 0.088085 | Acc 0.259871
# Test Loss 0.078911 | Acc 0.364341
# Model updated: Best-Acc = 0.364341
#
# Epoch 4:
# Time Usage:60.336944 | Training Loss 0.078385 | Acc 0.337217
# Test Loss 0.070936 | Acc 0.437339
# Model updated: Best-Acc = 0.437339
#
# Epoch 5:
# Time Usage:61.609678 | Training Loss 0.072056 | Acc 0.396602
# Test Loss 0.063467 | Acc 0.527778
# Model updated: Best-Acc = 0.527778
#
# Epoch 6:
# Time Usage:61.298751 | Training Loss 0.065454 | Acc 0.471845
# Test Loss 0.056689 | Acc 0.618863
# Model updated: Best-Acc = 0.618863
#
# Epoch 7:
# Time Usage:61.537601 | Training Loss 0.061525 | Acc 0.501618
# Test Loss 0.053241 | Acc 0.626615
# Model updated: Best-Acc = 0.626615
#
# Epoch 8:
# Time Usage:62.312745 | Training Loss 0.056831 | Acc 0.552913
# Test Loss 0.051020 | Acc 0.635659
# Model updated: Best-Acc = 0.635659
#
# Epoch 9:
# Time Usage:61.778188 | Training Loss 0.053528 | Acc 0.578964
# Test Loss 0.047982 | Acc 0.662145
# Model updated: Best-Acc = 0.662145
# best testing accuarcy: 0.6621447028423773
# 0.6621447028423773

# %% [markdown]
# #### GCN - expanding to k-th order neighborhood (connecting by k steps)

# %% [markdown]
# ##### Block duration = 6*TR

# %%
#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=5, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(6, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=32, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=32, bias=True)
#   )
# )
# 76480 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:751.486356 | Training Loss 0.054330 | Acc 0.032949
# Test Loss 0.053964 | Acc 0.067829
# Model updated: Best-Acc = 0.067829
#
# Epoch 1:
# Time Usage:756.365812 | Training Loss 0.050373 | Acc 0.104854
# Test Loss 0.044219 | Acc 0.224806
# Model updated: Best-Acc = 0.224806
#
# Epoch 2:
# Time Usage:749.146457 | Training Loss 0.042115 | Acc 0.225000
# Test Loss 0.036800 | Acc 0.420543
# Model updated: Best-Acc = 0.420543
#
# Epoch 3:
# Time Usage:750.736415 | Training Loss 0.037428 | Acc 0.302609
# Test Loss 0.031198 | Acc 0.503634
# Model updated: Best-Acc = 0.503634
#
# Epoch 4:
# Time Usage:758.153886 | Training Loss 0.032754 | Acc 0.373726
# Test Loss 0.028519 | Acc 0.561773
# Model updated: Best-Acc = 0.561773
#
# Epoch 5:
# Time Usage:760.858085 | Training Loss 0.030246 | Acc 0.425061
# Test Loss 0.027135 | Acc 0.584060
# Model updated: Best-Acc = 0.584060
#
# Epoch 6:
# Time Usage:760.000803 | Training Loss 0.027717 | Acc 0.467840
# Test Loss 0.023204 | Acc 0.640019
# Model updated: Best-Acc = 0.640019
#
# Epoch 7:
# Time Usage:760.135830 | Training Loss 0.026157 | Acc 0.492051
# Test Loss 0.023396 | Acc 0.651890
# Model updated: Best-Acc = 0.651890
#
# Epoch 8:
# Time Usage:769.701788 | Training Loss 0.024756 | Acc 0.524333
# Test Loss 0.022209 | Acc 0.679990
# Model updated: Best-Acc = 0.679990
#
# Epoch 9:
# Time Usage:775.918562 | Training Loss 0.023629 | Acc 0.545267
# Test Loss 0.018352 | Acc 0.728924
# Model updated: Best-Acc = 0.728924
# best testing accuarcy: 0.7289244186046512
# 0.7289244186046512

# %% [markdown]
# ##### Block duration = 8*TR

# %%
#Model params 
k_order = 5
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 8
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(8, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=24, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=24, bias=True)
#   )
# )
# 73712 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:462.142948 | Training Loss 0.066055 | Acc 0.053641
# Test Loss 0.063942 | Acc 0.129522
# Model updated: Best-Acc = 0.129522
#
# Epoch 1:
# Time Usage:466.012141 | Training Loss 0.059438 | Acc 0.141181
# Test Loss 0.053810 | Acc 0.273579
# Model updated: Best-Acc = 0.273579

# %% [markdown]
# ##### Block duration = 16*TR

# %%
#Model params 
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=5, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(16, 32, K=5)
#     (1): ChebConv(32, 32, K=5)
#     (2): ChebConv(32, 32, K=5)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=12, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=12, bias=True)
#   )
# )
# 70520 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:201.384051 | Training Loss 0.101701 | Acc 0.130583
# Test Loss 0.092205 | Acc 0.273256
# Model updated: Best-Acc = 0.273256
#
# Epoch 1:
# Time Usage:198.046426 | Training Loss 0.090437 | Acc 0.272168
# Test Loss 0.078106 | Acc 0.469638
# Model updated: Best-Acc = 0.469638
#
# Epoch 2:
# Time Usage:199.248237 | Training Loss 0.074368 | Acc 0.428317
# Test Loss 0.069438 | Acc 0.529716
# Model updated: Best-Acc = 0.529716
#
# Epoch 3:
# Time Usage:202.639385 | Training Loss 0.061068 | Acc 0.528964
# Test Loss 0.052838 | Acc 0.657623
# Model updated: Best-Acc = 0.657623
#
# Epoch 4:
# Time Usage:199.230864 | Training Loss 0.053356 | Acc 0.595793
# Test Loss 0.046365 | Acc 0.687984
# Model updated: Best-Acc = 0.687984
#
# Epoch 5:
# Time Usage:199.076016 | Training Loss 0.046615 | Acc 0.648220
# Test Loss 0.043152 | Acc 0.733204
# Model updated: Best-Acc = 0.733204
#
# Epoch 6:
# Time Usage:192.980917 | Training Loss 0.043036 | Acc 0.683172
# Test Loss 0.044789 | Acc 0.741602
# Model updated: Best-Acc = 0.741602
#
# Epoch 7:
# Time Usage:196.920206 | Training Loss 0.039063 | Acc 0.709061
# Test Loss 0.032701 | Acc 0.804910
# Model updated: Best-Acc = 0.804910
#
# Epoch 8:
# Time Usage:206.101389 | Training Loss 0.035077 | Acc 0.748382
# Test Loss 0.032270 | Acc 0.826227
# Model updated: Best-Acc = 0.826227
#
# Epoch 9:
# Time Usage:199.340281 | Training Loss 0.032031 | Acc 0.767314
# Test Loss 0.026870 | Acc 0.842377
# Model updated: Best-Acc = 0.842377
# best testing accuarcy: 0.8423772609819121
# 0.8423772609819121

# %% [markdown]
# ##### K = 8

# %% [markdown]
# ##### Block duration = 8*TR

# %%
#Model params 
k_order = 8
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)

# %% [markdown]
# ##### Block duration = 16*TR

# %%
#Model params 
k_order = 8
print(f'Block duration = {block_duration}')
loss_func = nn.CrossEntropyLoss()
filters = 32; num_layers = 2
num_epochs = 10 

#Model
model_test = ChebNet(block_duration, filters, n_labels, K=k_order, gcn_layer=num_layers,dropout=0.25)

model_test = model_test.to(device)
#adj_mat = adj_mat.to(device)
print(model_test)
print("{} paramters to be trained in the model\n".format(count_parameters(model_test)))

optimizer = optim.Adam(model_test.parameters(),lr=0.001, weight_decay=5e-4)

model_fit_evaluate(model_test, adj_mat, device, train_loader, test_loader, optimizer, loss_func, num_epochs)
# Out:
# Block duration = 16
# ChebNet(
#   (graph_features): ModuleList(
#     (0): ChebConv(16, 32, K=8)
#     (1): ChebConv(32, 32, K=8)
#     (2): ChebConv(32, 32, K=8)
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (pool): AdaptiveMaxPool2d(output_size=(360, 1))
#   (linear): Linear(in_features=360, out_features=12, bias=True)
#   (hidden2label): Sequential(
#     (0): Linear(in_features=360, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=128, out_features=32, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=32, out_features=12, bias=True)
#   )
# )
# 78200 paramters to be trained in the model
#
#
# Epoch 0:
# Time Usage:306.324696 | Training Loss 0.098958 | Acc 0.165534
# Test Loss 0.084819 | Acc 0.308786
# Model updated: Best-Acc = 0.308786
#
# Epoch 1:
# Time Usage:305.738673 | Training Loss 0.081162 | Acc 0.333172
# Test Loss 0.068377 | Acc 0.437339
# Model updated: Best-Acc = 0.437339
#
# Epoch 2:
# Time Usage:307.416768 | Training Loss 0.069510 | Acc 0.423625
# Test Loss 0.061427 | Acc 0.611757
# Model updated: Best-Acc = 0.611757
#
# Epoch 3:
# Time Usage:307.054118 | Training Loss 0.061045 | Acc 0.505502
# Test Loss 0.052534 | Acc 0.686693
# Model updated: Best-Acc = 0.686693
#
# Epoch 4:
# Time Usage:308.636461 | Training Loss 0.051783 | Acc 0.595307
# Test Loss 0.043862 | Acc 0.691860
# Model updated: Best-Acc = 0.691860
#
# Epoch 5:
# Time Usage:306.160362 | Training Loss 0.048807 | Acc 0.621197
# Test Loss 0.046105 | Acc 0.719638
# Model updated: Best-Acc = 0.719638
#
# Epoch 6:
# Time Usage:305.647310 | Training Loss 0.044677 | Acc 0.663269
# Test Loss 0.035496 | Acc 0.806848
# Model updated: Best-Acc = 0.806848
#
# Epoch 7:
# Time Usage:308.006093 | Training Loss 0.039529 | Acc 0.713754
# Test Loss 0.032011 | Acc 0.819121
# Model updated: Best-Acc = 0.819121
#
# Epoch 8:
# Time Usage:308.681564 | Training Loss 0.037587 | Acc 0.719741
# Test Loss 0.032694 | Acc 0.805556
#
# Epoch 9:
# Time Usage:306.334674 | Training Loss 0.034233 | Acc 0.745307
# Test Loss 0.031955 | Acc 0.815891
# best testing accuarcy: 0.8191214470284238
# 0.8191214470284238
